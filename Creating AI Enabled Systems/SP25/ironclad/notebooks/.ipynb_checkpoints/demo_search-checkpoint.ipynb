# %% [markdown]
# ### Andrew Taylor
# ### atayl136
# ### Creating AI Enabled Systems
#
# # Search Demo Notebook

# %% [markdown]
# # Demo Search Notebook
# This notebook demonstrates nearest neighbor search using the implemented FAISS index and various distance measures: **Euclidean**, **Cosine**, **Dot Product**, and **Minkowski**. We compute embeddings for gallery images, perform searches with 10 probe images, and report the rank positions.

# %%
import os
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

import sys
# Import FAISS (will be correctly handled in the index classes)
import faiss



# Add the parent directory to the path
# Replace '/path/to/parent/directory' with the actual path to your parent directory
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(parent_dir)

from modules.extraction.embedding import Embedding
from modules.extraction.preprocessing import Preprocessing


# Then import
from modules.retrieval.index.bruteforce import FaissBruteForce
from modules.retrieval.search import FaissSearch

# %%
import os

os.environ["KMP_DUPLICATE_LIB_OK"]="True"

# %%
from PIL import Image
import torch
import os
import glob
import numpy as np


# Initialize the preprocessing pipeline and embedding model once.
preprocessing = Preprocessing(image_size=160)
device = 'cpu'
embedding_model = Embedding(pretrained='casia-webface', device=device)

def compute_embedding(image_path):
    # Open and preprocess the image.
    image = Image.open(image_path).convert("RGB")
    processed_image = preprocessing.process(image)
    # Compute the embedding.
    embedding_vector = embedding_model.encode(processed_image)
    return embedding_vector

def get_first_image_from_folder(folder_path):
    """Get the first valid image file from a folder, skipping problematic files."""
    valid_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']
    
    try:
        for filename in os.listdir(folder_path):
            # Skip files starting with ._ (macOS metadata files)
            if filename.startswith('._'):
                continue
                
            file_path = os.path.join(folder_path, filename)
            if os.path.isfile(file_path) and any(file_path.lower().endswith(ext) for ext in valid_extensions):
                # Verify it's a valid image before returning
                try:
                    with Image.open(file_path) as img:
                        # Just accessing a property forces PIL to validate the file
                        img.format
                    return file_path
                except Exception:
                    # Skip this file if PIL can't open it
                    continue
    except Exception as e:
        print(f"Error accessing folder {folder_path}: {e}")
    
    return None

gallery_dir = '..\storage\multi_image_gallery'
folder_paths = glob.glob(os.path.join(gallery_dir, '*'))
print(f"Found {len(folder_paths)} folders in gallery.")

embeddings = []
metadata = []
successful_count = 0
error_count = 0

for folder_path in folder_paths:
    try:
        img_path = get_first_image_from_folder(folder_path)
        if img_path:
            try:
                embedding = compute_embedding(img_path)
                embeddings.append(embedding)
                metadata.append(os.path.basename(folder_path))
                successful_count += 1
                if successful_count % 10 == 0:
                    print(f"Successfully processed {successful_count} folders")
            except Exception as e:
                error_count += 1
                print(f"Error processing image {img_path}: {e}")
        else:
            print(f"No valid images found in folder: {folder_path}")
    except Exception as e:
        print(f"Fatal error with folder {folder_path}: {e}")

print(f"Processing complete. Success: {successful_count}, Errors: {error_count}")

embeddings = np.array(embeddings)
print(f"Created embeddings for {len(embeddings)} folders")

# Build a FAISS BruteForce index with Euclidean metric for demonstration.
faiss_index = FaissBruteForce(dim=512, metric='euclidean')
faiss_index.add_embeddings(embeddings, metadata)
print("Gallery embeddings indexed.")
# Out:
# <>:47: SyntaxWarning: invalid escape sequence '\s'
# <>:47: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Putna\AppData\Local\Temp\ipykernel_28604\3473531759.py:47: SyntaxWarning: invalid escape sequence '\s'
#   gallery_dir = '..\storage\multi_image_gallery'
# Found 1000 folders in gallery.
# Successfully processed 10 folders
# Successfully processed 20 folders
# Successfully processed 30 folders
# Successfully processed 40 folders
# Successfully processed 50 folders
# Successfully processed 60 folders
# Successfully processed 70 folders
# Successfully processed 80 folders
# Successfully processed 90 folders
# Successfully processed 100 folders
# Successfully processed 110 folders
# Successfully processed 120 folders
# Successfully processed 130 folders
# Successfully processed 140 folders
# Successfully processed 150 folders
# Successfully processed 160 folders
# Successfully processed 170 folders
# Successfully processed 180 folders
# Successfully processed 190 folders
# Successfully processed 200 folders
# Successfully processed 210 folders
# Successfully processed 220 folders
# Successfully processed 230 folders
# Successfully processed 240 folders
# Successfully processed 250 folders
# Successfully processed 260 folders
# Successfully processed 270 folders
# Successfully processed 280 folders
# Successfully processed 290 folders
# Successfully processed 300 folders
# Successfully processed 310 folders
# Successfully processed 320 folders
# Successfully processed 330 folders
# Successfully processed 340 folders
# Successfully processed 350 folders
# Successfully processed 360 folders
# Successfully processed 370 folders
# Successfully processed 380 folders
# Successfully processed 390 folders
# Successfully processed 400 folders
# Successfully processed 410 folders
# Successfully processed 420 folders
# Successfully processed 430 folders
# Successfully processed 440 folders
# Successfully processed 450 folders
# Successfully processed 460 folders
# Successfully processed 470 folders
# Successfully processed 480 folders
# Successfully processed 490 folders
# Successfully processed 500 folders
# Successfully processed 510 folders
# Successfully processed 520 folders
# Successfully processed 530 folders
# Successfully processed 540 folders
# Successfully processed 550 folders
# Successfully processed 560 folders
# Successfully processed 570 folders
# Successfully processed 580 folders
# Successfully processed 590 folders
# Successfully processed 600 folders
# Successfully processed 610 folders
# Successfully processed 620 folders
# Successfully processed 630 folders
# Successfully processed 640 folders
# Successfully processed 650 folders
# Successfully processed 660 folders
# Successfully processed 670 folders
# Successfully processed 680 folders
# Successfully processed 690 folders
# Successfully processed 700 folders
# Successfully processed 710 folders
# Successfully processed 720 folders
# Successfully processed 730 folders
# Successfully processed 740 folders
# Successfully processed 750 folders
# Successfully processed 760 folders
# Successfully processed 770 folders
# Successfully processed 780 folders
# Successfully processed 790 folders
# Successfully processed 800 folders
# Successfully processed 810 folders
# Successfully processed 820 folders
# Successfully processed 830 folders
# Successfully processed 840 folders
# Successfully processed 850 folders
# Successfully processed 860 folders
# Successfully processed 870 folders
# Successfully processed 880 folders
# Successfully processed 890 folders
# Successfully processed 900 folders
# Successfully processed 910 folders
# Successfully processed 920 folders
# Successfully processed 930 folders
# Successfully processed 940 folders
# Successfully processed 950 folders
# Successfully processed 960 folders
# Successfully processed 970 folders
# Successfully processed 980 folders
# Successfully processed 990 folders
# Successfully processed 1000 folders
# Processing complete. Success: 1000, Errors: 0
# Created embeddings for 1000 folders
# Gallery embeddings indexed.

# %%
# Step 2: Load probe images and compute embeddings
print("\nStep 2: Processing probe images...")
probe_dir = '../storage/probe'
probe_folders = glob.glob(os.path.join(probe_dir, '*'))

# Make sure we don't select more probes than are available
num_probes = min(10, len(probe_folders))
probe_folders = np.random.choice(probe_folders, size=num_probes, replace=False)

probe_embeddings = []
probe_metadata = []

print("Selected probe images:")
for i, folder_path in enumerate(probe_folders):
    img_path = get_first_image_from_folder(folder_path)
    if img_path:
        try:
            probe_embedding = compute_embedding(img_path)
            # Convert to numpy immediately
            probe_embeddings.append(probe_embedding)
            probe_metadata.append(os.path.basename(folder_path))
            print(f"Probe {i+1}: {os.path.basename(folder_path)}")
        except Exception as e:
            print(f"Error processing probe image {img_path}: {e}")
    else:
        print(f"No valid image in probe folder: {folder_path}")

probe_embeddings = np.array(probe_embeddings, dtype=np.float32)
print(f"Created embeddings for {len(probe_embeddings)} probe folders with shape {probe_embeddings.shape}")

# Step 3: Define metrics and perform searches
distance_metrics = ['euclidean', 'cosine', 'dot_product', 'minkowski']
k = 5  # Retrieve top 5 nearest neighbors for each probe

# Dictionary to store results for each metric
results = {metric: [] for metric in distance_metrics}
# Out:
# Step 2: Processing probe images...
# Selected probe images:
# Probe 1: Daniela_Hantuchova
# Probe 2: Kim_Ryong-sung
# Probe 3: Rick_Romley
# Probe 4: Donatella_Versace
# Probe 5: Steven_Spielberg
# Probe 6: George_Lopez
# Probe 7: Paul_McCartney
# Probe 8: Larry_Coker
# Probe 9: Ann_Veneman
# Probe 10: Alec_Baldwin
# Created embeddings for 10 probe folders with shape (10, 512)

# %%
#searcher = FaissSearch(faiss_index, metric="euclidean")
#distances, indices, meta_results = searcher.search(probe, k=5)
#print(f"  Search completed successfully")

# %%
print("\nStep 3: Performing searches with different distance metrics...")

for metric in distance_metrics:
    print(f"\n=== Distance metric: {metric} ===")
    
    # Create a fresh index for each metric
    if metric == 'minkowski':
        # For Minkowski, use euclidean with p=3 in the search
        faiss_index = FaissBruteForce(dim=embeddings.shape[1], metric='euclidean')
    else:
        faiss_index = FaissBruteForce(dim=embeddings.shape[1], metric=metric)
    
    # Add embeddings to the fresh index
    faiss_index.add_embeddings(embeddings, metadata)
    print(f"Created {metric} index with {faiss_index.index.ntotal} vectors")
    
    # Create searcher for this metric
    searcher = FaissSearch(faiss_index, metric=metric, p=3)  # p=3 for Minkowski
    
    # Dictionary to store probe results for this metric
    metric_results = []
    
    # Search for each probe
    for i, probe in enumerate(probe_embeddings):
        probe_name = probe_metadata[i]
        print(f"\nProbe {i+1}/{len(probe_embeddings)}: {probe_name}")
        
        try:
            # Ensure probe is correct format
            probe = np.ascontiguousarray(probe, dtype=np.float32)
            
            # Perform search
            distances, indices, meta_results = searcher.search(probe, k=k)
            
            # Store results
            probe_result = {
                'probe': probe_name,
                'matches': []
            }
            
            print(f"Top {k} matches:")
            for rank, (dist, match) in enumerate(zip(distances[0], meta_results), start=1):
                match_info = {
                    'rank': rank,
                    'name': match,
                    'distance': float(dist)
                }
                probe_result['matches'].append(match_info)
                print(f"  Rank {rank}: {match} (Distance: {dist:.4f})")
            
            metric_results.append(probe_result)
            
        except Exception as e:
            print(f"Error searching for probe {probe_name}: {str(e)}")
            import traceback
            traceback.print_exc()
    
    # Store all results for this metric
    results[metric] = metric_results
    print(f"Completed search with {metric} metric")

# Step 4: Print summary report
print("\n=== SEARCH RESULTS SUMMARY ===")
for metric in distance_metrics:
    print(f"\n--- {metric.upper()} METRIC ---")
    for probe_result in results[metric]:
        probe_name = probe_result['probe']
        print(f"Probe: {probe_name}")
        print("  Rank    | Match                    | Distance")
        print("  --------|--------------------------|---------")
        for match in probe_result['matches']:
            print(f"  {match['rank']:<7} | {match['name']:<24} | {match['distance']:.4f}")
        print()
# Out:
# Step 3: Performing searches with different distance metrics...
#
# === Distance metric: euclidean ===
# Created euclidean index with 1000 vectors
#
# Probe 1/10: Daniela_Hantuchova
# Top 5 matches:
#   Rank 1: Augustin_Calleri (Distance: 0.1098)
#   Rank 2: Monica_Bellucci (Distance: 0.1213)
#   Rank 3: Isaiah_Washington (Distance: 0.1320)
#   Rank 4: Angelo_Reyes (Distance: 0.1362)
#   Rank 5: Nicanor_Duarte_Frutos (Distance: 0.1398)
#
# Probe 2/10: Kim_Ryong-sung
# Top 5 matches:
#   Rank 1: Sachiko_Yamada (Distance: 0.1147)
#   Rank 2: Alberto_Fujimori (Distance: 0.1228)
#   Rank 3: Keira_Knightley (Distance: 0.1262)
#   Rank 4: Charlotte_Rampling (Distance: 0.1384)
#   Rank 5: Stanley_Tong (Distance: 0.1389)
#
# Probe 3/10: Rick_Romley
# Top 5 matches:
#   Rank 1: Joan_Claybrook (Distance: 0.5574)
#   Rank 2: John_F_Kennedy_Jr (Distance: 0.6059)
#   Rank 3: Francis_Mer (Distance: 0.6148)
#   Rank 4: Eduardo_Duhalde (Distance: 0.6198)
#   Rank 5: Paul_ONeill (Distance: 0.6628)
#
# Probe 4/10: Donatella_Versace
# Top 5 matches:
#   Rank 1: Barbra_Streisand (Distance: 0.1677)
#   Rank 2: Iva_Majoli (Distance: 0.1943)
#   Rank 3: Drew_Barrymore (Distance: 0.1976)
#   Rank 4: Albert_Costa (Distance: 0.2000)
#   Rank 5: Edward_Lu (Distance: 0.2146)
#
# Probe 5/10: Steven_Spielberg
# Top 5 matches:
#   Rank 1: Chen_Liang_Yu (Distance: 0.2200)
#   Rank 2: Robert_Stack (Distance: 0.2232)
#   Rank 3: Jonathan_Mostow (Distance: 0.2271)
#   Rank 4: Liu_Mingkang (Distance: 0.2332)
#   Rank 5: Robin_McLaurin_Williams (Distance: 0.2410)
#
# Probe 6/10: George_Lopez
# Top 5 matches:
#   Rank 1: Saparmurat_Niyazov (Distance: 0.1693)
#   Rank 2: Cristina_Saralegui (Distance: 0.1911)
#   Rank 3: Wang_Yingfan (Distance: 0.1921)
#   Rank 4: Anthony_LaPaglia (Distance: 0.1956)
#   Rank 5: Nora_Bendijo (Distance: 0.1999)
#
# Probe 7/10: Paul_McCartney
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.1569)
#   Rank 2: Chang_Dae-whan (Distance: 0.1634)
#   Rank 3: Saddam_Hussein (Distance: 0.1800)
#   Rank 4: Albert_Costa (Distance: 0.1838)
#   Rank 5: Celine_Dion (Distance: 0.1884)
#
# Probe 8/10: Larry_Coker
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.1710)
#   Rank 2: Saparmurat_Niyazov (Distance: 0.1715)
#   Rank 3: Albert_Costa (Distance: 0.1822)
#   Rank 4: Nora_Bendijo (Distance: 0.1836)
#   Rank 5: Anthony_LaPaglia (Distance: 0.1908)
#
# Probe 9/10: Ann_Veneman
# Top 5 matches:
#   Rank 1: Carol_Burnett (Distance: 0.1753)
#   Rank 2: George_Lopez (Distance: 0.1835)
#   Rank 3: Gian_Marco (Distance: 0.1851)
#   Rank 4: Martin_Brodeur (Distance: 0.1856)
#   Rank 5: Marco_Antonio_Barrera (Distance: 0.1894)
#
# Probe 10/10: Alec_Baldwin
# Top 5 matches:
#   Rank 1: Kenneth_Branagh (Distance: 0.2704)
#   Rank 2: Barry_Alvarez (Distance: 0.2862)
#   Rank 3: Spencer_Abraham (Distance: 0.2886)
#   Rank 4: Juan_Valencia_Osorio (Distance: 0.2897)
#   Rank 5: Michelle_Yeoh (Distance: 0.2945)
# Completed search with euclidean metric
#
# === Distance metric: cosine ===
# Created cosine index with 1000 vectors
#
# Probe 1/10: Daniela_Hantuchova
# Top 5 matches:
#   Rank 1: Augustin_Calleri (Distance: 0.9451)
#   Rank 2: Monica_Bellucci (Distance: 0.9394)
#   Rank 3: Isaiah_Washington (Distance: 0.9340)
#   Rank 4: Angelo_Reyes (Distance: 0.9319)
#   Rank 5: Nicanor_Duarte_Frutos (Distance: 0.9301)
#
# Probe 2/10: Kim_Ryong-sung
# Top 5 matches:
#   Rank 1: Sachiko_Yamada (Distance: 0.9426)
#   Rank 2: Alberto_Fujimori (Distance: 0.9386)
#   Rank 3: Keira_Knightley (Distance: 0.9369)
#   Rank 4: Charlotte_Rampling (Distance: 0.9308)
#   Rank 5: Stanley_Tong (Distance: 0.9306)
#
# Probe 3/10: Rick_Romley
# Top 5 matches:
#   Rank 1: Joan_Claybrook (Distance: 0.7213)
#   Rank 2: John_F_Kennedy_Jr (Distance: 0.6971)
#   Rank 3: Francis_Mer (Distance: 0.6926)
#   Rank 4: Eduardo_Duhalde (Distance: 0.6901)
#   Rank 5: Paul_ONeill (Distance: 0.6686)
#
# Probe 4/10: Donatella_Versace
# Top 5 matches:
#   Rank 1: Barbra_Streisand (Distance: 0.9161)
#   Rank 2: Iva_Majoli (Distance: 0.9029)
#   Rank 3: Drew_Barrymore (Distance: 0.9012)
#   Rank 4: Albert_Costa (Distance: 0.9000)
#   Rank 5: Edward_Lu (Distance: 0.8927)
#
# Probe 5/10: Steven_Spielberg
# Top 5 matches:
#   Rank 1: Chen_Liang_Yu (Distance: 0.8900)
#   Rank 2: Robert_Stack (Distance: 0.8884)
#   Rank 3: Jonathan_Mostow (Distance: 0.8865)
#   Rank 4: Liu_Mingkang (Distance: 0.8834)
#   Rank 5: Robin_McLaurin_Williams (Distance: 0.8795)
#
# Probe 6/10: George_Lopez
# Top 5 matches:
#   Rank 1: Saparmurat_Niyazov (Distance: 0.9154)
#   Rank 2: Cristina_Saralegui (Distance: 0.9045)
#   Rank 3: Wang_Yingfan (Distance: 0.9039)
#   Rank 4: Anthony_LaPaglia (Distance: 0.9022)
#   Rank 5: Nora_Bendijo (Distance: 0.9000)
#
# Probe 7/10: Paul_McCartney
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.9216)
#   Rank 2: Chang_Dae-whan (Distance: 0.9183)
#   Rank 3: Saddam_Hussein (Distance: 0.9100)
#   Rank 4: Albert_Costa (Distance: 0.9081)
#   Rank 5: Celine_Dion (Distance: 0.9058)
#
# Probe 8/10: Larry_Coker
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.9145)
#   Rank 2: Saparmurat_Niyazov (Distance: 0.9143)
#   Rank 3: Albert_Costa (Distance: 0.9089)
#   Rank 4: Nora_Bendijo (Distance: 0.9082)
#   Rank 5: Anthony_LaPaglia (Distance: 0.9046)
#
# Probe 9/10: Ann_Veneman
# Top 5 matches:
#   Rank 1: Carol_Burnett (Distance: 0.9123)
#   Rank 2: George_Lopez (Distance: 0.9082)
#   Rank 3: Gian_Marco (Distance: 0.9075)
#   Rank 4: Martin_Brodeur (Distance: 0.9072)
#   Rank 5: Marco_Antonio_Barrera (Distance: 0.9053)
#
# Probe 10/10: Alec_Baldwin
# Top 5 matches:
#   Rank 1: Kenneth_Branagh (Distance: 0.8648)
#   Rank 2: Barry_Alvarez (Distance: 0.8569)
#   Rank 3: Spencer_Abraham (Distance: 0.8557)
#   Rank 4: Juan_Valencia_Osorio (Distance: 0.8551)
#   Rank 5: Michelle_Yeoh (Distance: 0.8528)
# Completed search with cosine metric
#
# === Distance metric: dot_product ===
# Created dot_product index with 1000 vectors
#
# Probe 1/10: Daniela_Hantuchova
# Top 5 matches:
#   Rank 1: Augustin_Calleri (Distance: 0.9451)
#   Rank 2: Monica_Bellucci (Distance: 0.9394)
#   Rank 3: Isaiah_Washington (Distance: 0.9340)
#   Rank 4: Angelo_Reyes (Distance: 0.9319)
#   Rank 5: Nicanor_Duarte_Frutos (Distance: 0.9301)
#
# Probe 2/10: Kim_Ryong-sung
# Top 5 matches:
#   Rank 1: Sachiko_Yamada (Distance: 0.9426)
#   Rank 2: Alberto_Fujimori (Distance: 0.9386)
#   Rank 3: Keira_Knightley (Distance: 0.9369)
#   Rank 4: Charlotte_Rampling (Distance: 0.9308)
#   Rank 5: Stanley_Tong (Distance: 0.9306)
#
# Probe 3/10: Rick_Romley
# Top 5 matches:
#   Rank 1: Joan_Claybrook (Distance: 0.7213)
#   Rank 2: John_F_Kennedy_Jr (Distance: 0.6971)
#   Rank 3: Francis_Mer (Distance: 0.6926)
#   Rank 4: Eduardo_Duhalde (Distance: 0.6901)
#   Rank 5: Paul_ONeill (Distance: 0.6686)
#
# Probe 4/10: Donatella_Versace
# Top 5 matches:
#   Rank 1: Barbra_Streisand (Distance: 0.9161)
#   Rank 2: Iva_Majoli (Distance: 0.9029)
#   Rank 3: Drew_Barrymore (Distance: 0.9012)
#   Rank 4: Albert_Costa (Distance: 0.9000)
#   Rank 5: Edward_Lu (Distance: 0.8927)
#
# Probe 5/10: Steven_Spielberg
# Top 5 matches:
#   Rank 1: Chen_Liang_Yu (Distance: 0.8900)
#   Rank 2: Robert_Stack (Distance: 0.8884)
#   Rank 3: Jonathan_Mostow (Distance: 0.8865)
#   Rank 4: Liu_Mingkang (Distance: 0.8834)
#   Rank 5: Robin_McLaurin_Williams (Distance: 0.8795)
#
# Probe 6/10: George_Lopez
# Top 5 matches:
#   Rank 1: Saparmurat_Niyazov (Distance: 0.9154)
#   Rank 2: Cristina_Saralegui (Distance: 0.9045)
#   Rank 3: Wang_Yingfan (Distance: 0.9039)
#   Rank 4: Anthony_LaPaglia (Distance: 0.9022)
#   Rank 5: Nora_Bendijo (Distance: 0.9000)
#
# Probe 7/10: Paul_McCartney
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.9216)
#   Rank 2: Chang_Dae-whan (Distance: 0.9183)
#   Rank 3: Saddam_Hussein (Distance: 0.9100)
#   Rank 4: Albert_Costa (Distance: 0.9081)
#   Rank 5: Celine_Dion (Distance: 0.9058)
#
# Probe 8/10: Larry_Coker
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.9145)
#   Rank 2: Saparmurat_Niyazov (Distance: 0.9143)
#   Rank 3: Albert_Costa (Distance: 0.9089)
#   Rank 4: Nora_Bendijo (Distance: 0.9082)
#   Rank 5: Anthony_LaPaglia (Distance: 0.9046)
#
# Probe 9/10: Ann_Veneman
# Top 5 matches:
#   Rank 1: Carol_Burnett (Distance: 0.9123)
#   Rank 2: George_Lopez (Distance: 0.9082)
#   Rank 3: Gian_Marco (Distance: 0.9075)
#   Rank 4: Martin_Brodeur (Distance: 0.9072)
#   Rank 5: Marco_Antonio_Barrera (Distance: 0.9053)
#
# Probe 10/10: Alec_Baldwin
# Top 5 matches:
#   Rank 1: Kenneth_Branagh (Distance: 0.8648)
#   Rank 2: Barry_Alvarez (Distance: 0.8569)
#   Rank 3: Spencer_Abraham (Distance: 0.8557)
#   Rank 4: Juan_Valencia_Osorio (Distance: 0.8551)
#   Rank 5: Michelle_Yeoh (Distance: 0.8528)
# Completed search with dot_product metric
#
# === Distance metric: minkowski ===
# Created minkowski index with 1000 vectors
#
# Probe 1/10: Daniela_Hantuchova
# Top 5 matches:
#   Rank 1: Augustin_Calleri (Distance: 0.1359)
#   Rank 2: Monica_Bellucci (Distance: 0.1433)
#   Rank 3: Isaiah_Washington (Distance: 0.1513)
#   Rank 4: Angelo_Reyes (Distance: 0.1535)
#   Rank 5: Nicanor_Duarte_Frutos (Distance: 0.1544)
#
# Probe 2/10: Kim_Ryong-sung
# Top 5 matches:
#   Rank 1: Sachiko_Yamada (Distance: 0.1378)
#   Rank 2: Alberto_Fujimori (Distance: 0.1433)
#   Rank 3: Keira_Knightley (Distance: 0.1466)
#   Rank 4: Stanley_Tong (Distance: 0.1508)
#   Rank 5: Colin_Powell (Distance: 0.1519)
#
# Probe 3/10: Rick_Romley
# Top 5 matches:
#   Rank 1: Joan_Claybrook (Distance: 0.3050)
#   Rank 2: John_F_Kennedy_Jr (Distance: 0.3204)
#   Rank 3: Francis_Mer (Distance: 0.3230)
#   Rank 4: Eduardo_Duhalde (Distance: 0.3255)
#   Rank 5: Paul_ONeill (Distance: 0.3336)
#
# Probe 4/10: Donatella_Versace
# Top 5 matches:
#   Rank 1: Barbra_Streisand (Distance: 0.1711)
#   Rank 2: Drew_Barrymore (Distance: 0.1816)
#   Rank 3: Iva_Majoli (Distance: 0.1830)
#   Rank 4: Albert_Costa (Distance: 0.1837)
#   Rank 5: Edward_Lu (Distance: 0.1888)
#
# Probe 5/10: Steven_Spielberg
# Top 5 matches:
#   Rank 1: Chen_Liang_Yu (Distance: 0.1921)
#   Rank 2: Jonathan_Mostow (Distance: 0.1944)
#   Rank 3: Robert_Stack (Distance: 0.1947)
#   Rank 4: Liu_Mingkang (Distance: 0.1978)
#   Rank 5: Robin_McLaurin_Williams (Distance: 0.2026)
#
# Probe 6/10: George_Lopez
# Top 5 matches:
#   Rank 1: Saparmurat_Niyazov (Distance: 0.1700)
#   Rank 2: Cristina_Saralegui (Distance: 0.1809)
#   Rank 3: Wang_Yingfan (Distance: 0.1823)
#   Rank 4: Anthony_LaPaglia (Distance: 0.1830)
#   Rank 5: Nora_Bendijo (Distance: 0.1864)
#
# Probe 7/10: Paul_McCartney
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.1615)
#   Rank 2: Chang_Dae-whan (Distance: 0.1624)
#   Rank 3: Saddam_Hussein (Distance: 0.1730)
#   Rank 4: Albert_Costa (Distance: 0.1761)
#   Rank 5: Mike_Babcock (Distance: 0.1786)
#
# Probe 8/10: Larry_Coker
# Top 5 matches:
#   Rank 1: Hassan_Wirajuda (Distance: 0.1699)
#   Rank 2: Saparmurat_Niyazov (Distance: 0.1713)
#   Rank 3: Nora_Bendijo (Distance: 0.1758)
#   Rank 4: Albert_Costa (Distance: 0.1772)
#   Rank 5: Anthony_LaPaglia (Distance: 0.1782)
#
# Probe 9/10: Ann_Veneman
# Top 5 matches:
#   Rank 1: Carol_Burnett (Distance: 0.1721)
#   Rank 2: Martin_Brodeur (Distance: 0.1757)
#   Rank 3: Gian_Marco (Distance: 0.1760)
#   Rank 4: George_Lopez (Distance: 0.1777)
#   Rank 5: Saparmurat_Niyazov (Distance: 0.1794)
#
# Probe 10/10: Alec_Baldwin
# Top 5 matches:
#   Rank 1: Kenneth_Branagh (Distance: 0.2103)
#   Rank 2: Barry_Alvarez (Distance: 0.2178)
#   Rank 3: Spencer_Abraham (Distance: 0.2181)
#   Rank 4: Michelle_Yeoh (Distance: 0.2209)
#   Rank 5: Juan_Valencia_Osorio (Distance: 0.2218)
# Completed search with minkowski metric
#
# === SEARCH RESULTS SUMMARY ===
#
# --- EUCLIDEAN METRIC ---
# Probe: Daniela_Hantuchova
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Augustin_Calleri         | 0.1098
#   2       | Monica_Bellucci          | 0.1213
#   3       | Isaiah_Washington        | 0.1320
#   4       | Angelo_Reyes             | 0.1362
#   5       | Nicanor_Duarte_Frutos    | 0.1398
#
# Probe: Kim_Ryong-sung
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Sachiko_Yamada           | 0.1147
#   2       | Alberto_Fujimori         | 0.1228
#   3       | Keira_Knightley          | 0.1262
#   4       | Charlotte_Rampling       | 0.1384
#   5       | Stanley_Tong             | 0.1389
#
# Probe: Rick_Romley
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Joan_Claybrook           | 0.5574
#   2       | John_F_Kennedy_Jr        | 0.6059
#   3       | Francis_Mer              | 0.6148
#   4       | Eduardo_Duhalde          | 0.6198
#   5       | Paul_ONeill              | 0.6628
#
# Probe: Donatella_Versace
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Barbra_Streisand         | 0.1677
#   2       | Iva_Majoli               | 0.1943
#   3       | Drew_Barrymore           | 0.1976
#   4       | Albert_Costa             | 0.2000
#   5       | Edward_Lu                | 0.2146
#
# Probe: Steven_Spielberg
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Chen_Liang_Yu            | 0.2200
#   2       | Robert_Stack             | 0.2232
#   3       | Jonathan_Mostow          | 0.2271
#   4       | Liu_Mingkang             | 0.2332
#   5       | Robin_McLaurin_Williams  | 0.2410
#
# Probe: George_Lopez
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Saparmurat_Niyazov       | 0.1693
#   2       | Cristina_Saralegui       | 0.1911
#   3       | Wang_Yingfan             | 0.1921
#   4       | Anthony_LaPaglia         | 0.1956
#   5       | Nora_Bendijo             | 0.1999
#
# Probe: Paul_McCartney
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.1569
#   2       | Chang_Dae-whan           | 0.1634
#   3       | Saddam_Hussein           | 0.1800
#   4       | Albert_Costa             | 0.1838
#   5       | Celine_Dion              | 0.1884
#
# Probe: Larry_Coker
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.1710
#   2       | Saparmurat_Niyazov       | 0.1715
#   3       | Albert_Costa             | 0.1822
#   4       | Nora_Bendijo             | 0.1836
#   5       | Anthony_LaPaglia         | 0.1908
#
# Probe: Ann_Veneman
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Carol_Burnett            | 0.1753
#   2       | George_Lopez             | 0.1835
#   3       | Gian_Marco               | 0.1851
#   4       | Martin_Brodeur           | 0.1856
#   5       | Marco_Antonio_Barrera    | 0.1894
#
# Probe: Alec_Baldwin
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Kenneth_Branagh          | 0.2704
#   2       | Barry_Alvarez            | 0.2862
#   3       | Spencer_Abraham          | 0.2886
#   4       | Juan_Valencia_Osorio     | 0.2897
#   5       | Michelle_Yeoh            | 0.2945
#
#
# --- COSINE METRIC ---
# Probe: Daniela_Hantuchova
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Augustin_Calleri         | 0.9451
#   2       | Monica_Bellucci          | 0.9394
#   3       | Isaiah_Washington        | 0.9340
#   4       | Angelo_Reyes             | 0.9319
#   5       | Nicanor_Duarte_Frutos    | 0.9301
#
# Probe: Kim_Ryong-sung
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Sachiko_Yamada           | 0.9426
#   2       | Alberto_Fujimori         | 0.9386
#   3       | Keira_Knightley          | 0.9369
#   4       | Charlotte_Rampling       | 0.9308
#   5       | Stanley_Tong             | 0.9306
#
# Probe: Rick_Romley
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Joan_Claybrook           | 0.7213
#   2       | John_F_Kennedy_Jr        | 0.6971
#   3       | Francis_Mer              | 0.6926
#   4       | Eduardo_Duhalde          | 0.6901
#   5       | Paul_ONeill              | 0.6686
#
# Probe: Donatella_Versace
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Barbra_Streisand         | 0.9161
#   2       | Iva_Majoli               | 0.9029
#   3       | Drew_Barrymore           | 0.9012
#   4       | Albert_Costa             | 0.9000
#   5       | Edward_Lu                | 0.8927
#
# Probe: Steven_Spielberg
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Chen_Liang_Yu            | 0.8900
#   2       | Robert_Stack             | 0.8884
#   3       | Jonathan_Mostow          | 0.8865
#   4       | Liu_Mingkang             | 0.8834
#   5       | Robin_McLaurin_Williams  | 0.8795
#
# Probe: George_Lopez
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Saparmurat_Niyazov       | 0.9154
#   2       | Cristina_Saralegui       | 0.9045
#   3       | Wang_Yingfan             | 0.9039
#   4       | Anthony_LaPaglia         | 0.9022
#   5       | Nora_Bendijo             | 0.9000
#
# Probe: Paul_McCartney
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.9216
#   2       | Chang_Dae-whan           | 0.9183
#   3       | Saddam_Hussein           | 0.9100
#   4       | Albert_Costa             | 0.9081
#   5       | Celine_Dion              | 0.9058
#
# Probe: Larry_Coker
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.9145
#   2       | Saparmurat_Niyazov       | 0.9143
#   3       | Albert_Costa             | 0.9089
#   4       | Nora_Bendijo             | 0.9082
#   5       | Anthony_LaPaglia         | 0.9046
#
# Probe: Ann_Veneman
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Carol_Burnett            | 0.9123
#   2       | George_Lopez             | 0.9082
#   3       | Gian_Marco               | 0.9075
#   4       | Martin_Brodeur           | 0.9072
#   5       | Marco_Antonio_Barrera    | 0.9053
#
# Probe: Alec_Baldwin
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Kenneth_Branagh          | 0.8648
#   2       | Barry_Alvarez            | 0.8569
#   3       | Spencer_Abraham          | 0.8557
#   4       | Juan_Valencia_Osorio     | 0.8551
#   5       | Michelle_Yeoh            | 0.8528
#
#
# --- DOT_PRODUCT METRIC ---
# Probe: Daniela_Hantuchova
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Augustin_Calleri         | 0.9451
#   2       | Monica_Bellucci          | 0.9394
#   3       | Isaiah_Washington        | 0.9340
#   4       | Angelo_Reyes             | 0.9319
#   5       | Nicanor_Duarte_Frutos    | 0.9301
#
# Probe: Kim_Ryong-sung
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Sachiko_Yamada           | 0.9426
#   2       | Alberto_Fujimori         | 0.9386
#   3       | Keira_Knightley          | 0.9369
#   4       | Charlotte_Rampling       | 0.9308
#   5       | Stanley_Tong             | 0.9306
#
# Probe: Rick_Romley
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Joan_Claybrook           | 0.7213
#   2       | John_F_Kennedy_Jr        | 0.6971
#   3       | Francis_Mer              | 0.6926
#   4       | Eduardo_Duhalde          | 0.6901
#   5       | Paul_ONeill              | 0.6686
#
# Probe: Donatella_Versace
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Barbra_Streisand         | 0.9161
#   2       | Iva_Majoli               | 0.9029
#   3       | Drew_Barrymore           | 0.9012
#   4       | Albert_Costa             | 0.9000
#   5       | Edward_Lu                | 0.8927
#
# Probe: Steven_Spielberg
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Chen_Liang_Yu            | 0.8900
#   2       | Robert_Stack             | 0.8884
#   3       | Jonathan_Mostow          | 0.8865
#   4       | Liu_Mingkang             | 0.8834
#   5       | Robin_McLaurin_Williams  | 0.8795
#
# Probe: George_Lopez
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Saparmurat_Niyazov       | 0.9154
#   2       | Cristina_Saralegui       | 0.9045
#   3       | Wang_Yingfan             | 0.9039
#   4       | Anthony_LaPaglia         | 0.9022
#   5       | Nora_Bendijo             | 0.9000
#
# Probe: Paul_McCartney
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.9216
#   2       | Chang_Dae-whan           | 0.9183
#   3       | Saddam_Hussein           | 0.9100
#   4       | Albert_Costa             | 0.9081
#   5       | Celine_Dion              | 0.9058
#
# Probe: Larry_Coker
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.9145
#   2       | Saparmurat_Niyazov       | 0.9143
#   3       | Albert_Costa             | 0.9089
#   4       | Nora_Bendijo             | 0.9082
#   5       | Anthony_LaPaglia         | 0.9046
#
# Probe: Ann_Veneman
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Carol_Burnett            | 0.9123
#   2       | George_Lopez             | 0.9082
#   3       | Gian_Marco               | 0.9075
#   4       | Martin_Brodeur           | 0.9072
#   5       | Marco_Antonio_Barrera    | 0.9053
#
# Probe: Alec_Baldwin
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Kenneth_Branagh          | 0.8648
#   2       | Barry_Alvarez            | 0.8569
#   3       | Spencer_Abraham          | 0.8557
#   4       | Juan_Valencia_Osorio     | 0.8551
#   5       | Michelle_Yeoh            | 0.8528
#
#
# --- MINKOWSKI METRIC ---
# Probe: Daniela_Hantuchova
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Augustin_Calleri         | 0.1359
#   2       | Monica_Bellucci          | 0.1433
#   3       | Isaiah_Washington        | 0.1513
#   4       | Angelo_Reyes             | 0.1535
#   5       | Nicanor_Duarte_Frutos    | 0.1544
#
# Probe: Kim_Ryong-sung
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Sachiko_Yamada           | 0.1378
#   2       | Alberto_Fujimori         | 0.1433
#   3       | Keira_Knightley          | 0.1466
#   4       | Stanley_Tong             | 0.1508
#   5       | Colin_Powell             | 0.1519
#
# Probe: Rick_Romley
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Joan_Claybrook           | 0.3050
#   2       | John_F_Kennedy_Jr        | 0.3204
#   3       | Francis_Mer              | 0.3230
#   4       | Eduardo_Duhalde          | 0.3255
#   5       | Paul_ONeill              | 0.3336
#
# Probe: Donatella_Versace
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Barbra_Streisand         | 0.1711
#   2       | Drew_Barrymore           | 0.1816
#   3       | Iva_Majoli               | 0.1830
#   4       | Albert_Costa             | 0.1837
#   5       | Edward_Lu                | 0.1888
#
# Probe: Steven_Spielberg
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Chen_Liang_Yu            | 0.1921
#   2       | Jonathan_Mostow          | 0.1944
#   3       | Robert_Stack             | 0.1947
#   4       | Liu_Mingkang             | 0.1978
#   5       | Robin_McLaurin_Williams  | 0.2026
#
# Probe: George_Lopez
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Saparmurat_Niyazov       | 0.1700
#   2       | Cristina_Saralegui       | 0.1809
#   3       | Wang_Yingfan             | 0.1823
#   4       | Anthony_LaPaglia         | 0.1830
#   5       | Nora_Bendijo             | 0.1864
#
# Probe: Paul_McCartney
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.1615
#   2       | Chang_Dae-whan           | 0.1624
#   3       | Saddam_Hussein           | 0.1730
#   4       | Albert_Costa             | 0.1761
#   5       | Mike_Babcock             | 0.1786
#
# Probe: Larry_Coker
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Hassan_Wirajuda          | 0.1699
#   2       | Saparmurat_Niyazov       | 0.1713
#   3       | Nora_Bendijo             | 0.1758
#   4       | Albert_Costa             | 0.1772
#   5       | Anthony_LaPaglia         | 0.1782
#
# Probe: Ann_Veneman
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Carol_Burnett            | 0.1721
#   2       | Martin_Brodeur           | 0.1757
#   3       | Gian_Marco               | 0.1760
#   4       | George_Lopez             | 0.1777
#   5       | Saparmurat_Niyazov       | 0.1794
#
# Probe: Alec_Baldwin
#   Rank    | Match                    | Distance
#   --------|--------------------------|---------
#   1       | Kenneth_Branagh          | 0.2103
#   2       | Barry_Alvarez            | 0.2178
#   3       | Spencer_Abraham          | 0.2181
#   4       | Michelle_Yeoh            | 0.2209
#   5       | Juan_Valencia_Osorio     | 0.2218

# %% [markdown]
# ## Observations
#
# - **Euclidean**, **Cosine**, and **Dot Product** metrics yield different rankings, though cosine and dot product are often similar if embeddings are normalized.
# - The **Minkowski** and **Euclidean** metrics yielded the shortest distances.
# - The choice of distance measure can affect the ranking of nearest neighbors; further tuning and experiments are necessary to determine the best fit for the application.
