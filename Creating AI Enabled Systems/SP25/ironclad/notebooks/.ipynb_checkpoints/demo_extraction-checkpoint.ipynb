# %% [markdown]
# # Demonstration of Extraction Process

# %%
import os
from PIL import Image
import numpy as np
import torch
import sys


# Add the parent directory to the system path
sys.path.append(os.path.abspath(".."))

# Now you can import from the modules folder
from modules.extraction.preprocessing import Preprocessing
from modules.extraction.embedding import Embedding


def load_first_image(directory):
    """
    Load the first valid image file found in the given directory.
    Assumes image files have extensions .jpg or .png and ignores hidden/system files.
    """
    files = [f for f in os.listdir(directory)
             if f.lower().endswith(('.jpg', '.png')) and not f.startswith("._")]
    if not files:
        raise FileNotFoundError(f"No image files found in {directory}")
    files.sort()  # Ensure consistent order
    return os.path.join(directory, files[0])


def euclidean_distance(vec1, vec2):
    """Compute the Euclidean distance between two vectors."""
    return np.linalg.norm(vec1 - vec2)

# List of individuals to process
individuals = ['Drew_Barrymore', 'Warren_Buffett', 'Owen_Wilson', 'Nelson_Mandela', 'Ian_Thorpe']

# Dictionaries to store the file paths for probe and gallery images
probe_images = {}
gallery_images = {}


# Get the absolute path to the parent directory
parent_dir = os.path.abspath("..")

# Construct file paths for probe and gallery images using the parent directory
for person in individuals:
    probe_dir = os.path.join(parent_dir, "storage", "probe", person)
    gallery_dir = os.path.join(parent_dir, "storage", "multi_image_gallery", person)
    probe_images[person] = load_first_image(probe_dir)
    gallery_images[person] = load_first_image(gallery_dir)


print("Probe Images:")
for person, path in probe_images.items():
    print(f"{person}: {path}")

print("\nGallery Images:")
for person, path in gallery_images.items():
    print(f"{person}: {path}")

# Initialize the preprocessing pipeline
preprocessor = Preprocessing(image_size=160)

def process_and_encode(image_path, embedding_model):
    """
    Open the image, preprocess it, and compute its embedding using the given model.
    """
    image = Image.open(image_path)
    tensor = preprocessor.process(image)
    embedding = embedding_model.encode(tensor)
    return embedding

# Determine the device based on availability
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# Initialize two embedding models with different pretrained sources
embedding_casia = Embedding(pretrained='casia-webface', device=device)
embedding_vgg = Embedding(pretrained='vggface2', device=device)
# Out:
# Probe Images:
# Drew_Barrymore: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\probe\Drew_Barrymore\Drew_Barrymore_0002.jpg
# Warren_Buffett: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\probe\Warren_Buffett\Warren_Buffett_0002.jpg
# Owen_Wilson: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\probe\Owen_Wilson\Owen_Wilson_0002.jpg
# Nelson_Mandela: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\probe\Nelson_Mandela\Nelson_Mandela_0002.jpg
# Ian_Thorpe: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\probe\Ian_Thorpe\Ian_Thorpe_0002.jpg
#
# Gallery Images:
# Drew_Barrymore: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Drew_Barrymore\Drew_Barrymore_0001.jpg
# Warren_Buffett: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Warren_Buffett\Warren_Buffett_0001.jpg
# Owen_Wilson: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Owen_Wilson\Owen_Wilson_0001.jpg
# Nelson_Mandela: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nelson_Mandela\Nelson_Mandela_0001.jpg
# Ian_Thorpe: C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Ian_Thorpe\Ian_Thorpe_0001.jpg

# %% [markdown]
# #### **Task 1: Assignment Instructions:**
#
# Demonstrate the embedding capability of the service for 'cassia-webface' and 'vggface2'  by calculating the Euclidean distance of the following five probe images and their corresponding gallery images:
#
# - Drew Barrymore
# - Warren Buffet
# - Owen Wilson
# - Nelson Mandela
# - Ian Thorpe

# %%
results = {}

for person in individuals:
    # Process and encode the probe and gallery images using the "casia-webface" model
    emb_probe_casia = process_and_encode(probe_images[person], embedding_casia)
    emb_gallery_casia = process_and_encode(gallery_images[person], embedding_casia)
    dist_casia = euclidean_distance(emb_probe_casia, emb_gallery_casia)
    
    # Process and encode using the "vggface2" model
    emb_probe_vgg = process_and_encode(probe_images[person], embedding_vgg)
    emb_gallery_vgg = process_and_encode(gallery_images[person], embedding_vgg)
    dist_vgg = euclidean_distance(emb_probe_vgg, emb_gallery_vgg)
    
    results[person] = {"casia-webface": dist_casia, "vggface2": dist_vgg}

# Display the computed Euclidean distances
print("Euclidean distances between probe and gallery images:")
for person, distances in results.items():
    print(f"{person}: casia-webface = {distances['casia-webface']:.4f}, vggface2 = {distances['vggface2']:.4f}")
# Out:
# Euclidean distances between probe and gallery images:
# Drew_Barrymore: casia-webface = 0.5837, vggface2 = 1.0935
# Warren_Buffett: casia-webface = 0.9267, vggface2 = 0.9987
# Owen_Wilson: casia-webface = 0.7567, vggface2 = 0.5736
# Nelson_Mandela: casia-webface = 0.6206, vggface2 = 0.8532
# Ian_Thorpe: casia-webface = 0.6561, vggface2 = 1.1900

# %% [markdown]
# #### Observations:
#
# Here are some observations based on the computed Euclidean distances:
#
# - **Variation Between Models:**
#   For some individuals, the casia-webface model produces lower distances (e.g., Drew Barrymore, Nelson Mandela, Ian Thorpe), suggesting it might be more consistent for these faces. However, for Owen Wilson, vggface2 produces a lower distance, indicating that the performance can be subject-dependent.
#
# - **Model Sensitivity:**
#   The differences in distances might be attributed to how each model was trained. For example, casia-webface seems to generate embeddings that are closer for Drew Barrymore and Ian Thorpe, while vggface2 shows an advantage for Owen Wilson. Warren Buffett’s distances are quite similar across both models, hinting at consistent performance for that identity.
#
# - **Interpretation of Distances:**
#   Since Euclidean distance is a measure of similarity (lower means more similar), these results imply that for most individuals, casia-webface tends to produce embeddings that are slightly more similar between probe and gallery images, with the exception of Owen Wilson where vggface2 shows a better match. However, without a predefined threshold or further validation against negative pairs, these numbers primarily serve as relative indicators.

# %% [markdown]
# #

# %% [markdown]
# ---

# %% [markdown]
# #### **Task 2: Assignment Instructions:**
#
# Precompute the embeddings of ALL images stored in storage/gallery/*. For each of the five probe images, calculate the following distance against all the images in the gallery. Sort the embeddings from shortest to longest distance and print the images of the ten nearest neighbors and the name associated with each image. Note your observations.

# %%
def dot_product_distance(vec1, vec2):
    """
    Compute a distance based on the negative dot product.
    A higher dot product (more similar) gives a lower "distance".
    """
    return - np.dot(vec1, vec2)

def cosine_distance(vec1, vec2):
    """
    Compute the cosine distance between two vectors.
    Cosine distance is defined as 1 minus the cosine similarity.
    """
    cos_sim = np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))
    return 1 - cos_sim

def minkowski_distance(vec1, vec2, p=3):
    """
    Compute the Minkowski distance with order p (default p=3).
    """
    return np.sum(np.abs(vec1 - vec2) ** p) ** (1/p)

# %%
# Precompute embeddings for all images in the gallery.
gallery_embeddings = []

# Set the gallery base folder; adjust as needed.
gallery_base = os.path.join(parent_dir, "storage", "multi_image_gallery")

# List all subdirectories (each representing a person)
persons_in_gallery = [d for d in os.listdir(gallery_base) if os.path.isdir(os.path.join(gallery_base, d))]

for person in persons_in_gallery:
    person_dir = os.path.join(gallery_base, person)
    # List valid image files (exclude hidden files)
    image_files = [f for f in os.listdir(person_dir) if f.lower().endswith(('.jpg', '.png')) and not f.startswith("._")]
    image_files.sort()
    for img in image_files:
        img_path = os.path.join(person_dir, img)
        try:
            image = Image.open(img_path)
            tensor = preprocessor.process(image)
            # Using the casia-webface model for gallery embeddings
            embedding = embedding_casia.encode(tensor)
            gallery_embeddings.append({"person": person, "image_path": img_path, "embedding": embedding})
        except Exception as e:
            print(f"Error processing image {img_path}: {e}")

print(f"Precomputed embeddings for {len(gallery_embeddings)} gallery images.")
# Out:
# Precomputed embeddings for 2265 gallery images.

# %%
# For each probe image in our individuals list, compute distances against all gallery embeddings.
# We'll use the casia-webface embedding for consistency.
probe_results = {}

for person in individuals:
    probe_img_path = probe_images[person]
    # Process and compute the probe embedding
    image = Image.open(probe_img_path)
    tensor = preprocessor.process(image)
    probe_embedding = embedding_casia.encode(tensor)
    
    # Prepare dictionaries to store distances per metric
    distances = {"euclidean": [], "dot_product": [], "cosine": [], "minkowski": []}
    
    for gallery_entry in gallery_embeddings:
        g_embedding = gallery_entry["embedding"]
        d_euclid = euclidean_distance(probe_embedding, g_embedding)
        d_dot = dot_product_distance(probe_embedding, g_embedding)
        d_cos = cosine_distance(probe_embedding, g_embedding)
        d_mink = minkowski_distance(probe_embedding, g_embedding)
        
        distances["euclidean"].append((d_euclid, gallery_entry))
        distances["dot_product"].append((d_dot, gallery_entry))
        distances["cosine"].append((d_cos, gallery_entry))
        distances["minkowski"].append((d_mink, gallery_entry))
    
    # Sort each metric's list: from smallest to largest "distance"
    for metric in distances:
        distances[metric].sort(key=lambda x: x[0])
    
    probe_results[person] = distances

# Display the top 10 nearest neighbors for each probe image and for each metric.
for person, metrics in probe_results.items():
    print(f"\nResults for probe image of {person}:")
    for metric, results_list in metrics.items():
        print(f"\nTop 10 nearest neighbors using {metric} distance:")
        for rank, (dist_val, gallery_entry) in enumerate(results_list[:10], start=1):
            print(f"Rank {rank}: {gallery_entry['person']} - {gallery_entry['image_path']} with distance {dist_val:.4f}")
# Out:
# Results for probe image of Drew_Barrymore:
#
# Top 10 nearest neighbors using euclidean distance:
# Rank 1: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0007.jpg with distance 0.3953
# Rank 2: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0006.jpg with distance 0.3983
# Rank 3: Oscar_De_La_Hoya - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Oscar_De_La_Hoya\Oscar_De_La_Hoya_0005.jpg with distance 0.4025
# Rank 4: Dwayne_Johnson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dwayne_Johnson\Dwayne_Johnson_0001.jpg with distance 0.4046
# Rank 5: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0005.jpg with distance 0.4064
# Rank 6: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0003.jpg with distance 0.4121
# Rank 7: Taufik_Hidayat - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Taufik_Hidayat\Taufik_Hidayat_0001.jpg with distance 0.4173
# Rank 8: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0002.jpg with distance 0.4216
# Rank 9: Hillary_Clinton - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Hillary_Clinton\Hillary_Clinton_0007.jpg with distance 0.4242
# Rank 10: Jefferson_Perez - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jefferson_Perez\Jefferson_Perez_0001.jpg with distance 0.4317
#
# Top 10 nearest neighbors using dot_product distance:
# Rank 1: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0007.jpg with distance -0.9219
# Rank 2: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0006.jpg with distance -0.9207
# Rank 3: Oscar_De_La_Hoya - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Oscar_De_La_Hoya\Oscar_De_La_Hoya_0005.jpg with distance -0.9190
# Rank 4: Dwayne_Johnson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dwayne_Johnson\Dwayne_Johnson_0001.jpg with distance -0.9181
# Rank 5: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0005.jpg with distance -0.9174
# Rank 6: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0003.jpg with distance -0.9151
# Rank 7: Taufik_Hidayat - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Taufik_Hidayat\Taufik_Hidayat_0001.jpg with distance -0.9129
# Rank 8: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0002.jpg with distance -0.9111
# Rank 9: Hillary_Clinton - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Hillary_Clinton\Hillary_Clinton_0007.jpg with distance -0.9100
# Rank 10: Jefferson_Perez - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jefferson_Perez\Jefferson_Perez_0001.jpg with distance -0.9068
#
# Top 10 nearest neighbors using cosine distance:
# Rank 1: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0007.jpg with distance 0.0781
# Rank 2: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0006.jpg with distance 0.0793
# Rank 3: Oscar_De_La_Hoya - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Oscar_De_La_Hoya\Oscar_De_La_Hoya_0005.jpg with distance 0.0810
# Rank 4: Dwayne_Johnson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dwayne_Johnson\Dwayne_Johnson_0001.jpg with distance 0.0819
# Rank 5: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0005.jpg with distance 0.0826
# Rank 6: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0003.jpg with distance 0.0849
# Rank 7: Taufik_Hidayat - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Taufik_Hidayat\Taufik_Hidayat_0001.jpg with distance 0.0871
# Rank 8: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0002.jpg with distance 0.0889
# Rank 9: Hillary_Clinton - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Hillary_Clinton\Hillary_Clinton_0007.jpg with distance 0.0900
# Rank 10: Jefferson_Perez - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jefferson_Perez\Jefferson_Perez_0001.jpg with distance 0.0932
#
# Top 10 nearest neighbors using minkowski distance:
# Rank 1: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0007.jpg with distance 0.1623
# Rank 2: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0006.jpg with distance 0.1637
# Rank 3: Oscar_De_La_Hoya - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Oscar_De_La_Hoya\Oscar_De_La_Hoya_0005.jpg with distance 0.1652
# Rank 4: Dwayne_Johnson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dwayne_Johnson\Dwayne_Johnson_0001.jpg with distance 0.1667
# Rank 5: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0005.jpg with distance 0.1668
# Rank 6: Julie_Gerberding - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Julie_Gerberding\Julie_Gerberding_0003.jpg with distance 0.1692
# Rank 7: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0002.jpg with distance 0.1718
# Rank 8: Taufik_Hidayat - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Taufik_Hidayat\Taufik_Hidayat_0001.jpg with distance 0.1728
# Rank 9: Hillary_Clinton - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Hillary_Clinton\Hillary_Clinton_0007.jpg with distance 0.1759
# Rank 10: Ian_Thorpe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Ian_Thorpe\Ian_Thorpe_0001.jpg with distance 0.1766
#
# Results for probe image of Warren_Buffett:
#
# Top 10 nearest neighbors using euclidean distance:
# Rank 1: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0004.jpg with distance 0.4546
# Rank 2: Gordon_Campbell - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gordon_Campbell\Gordon_Campbell_0001.jpg with distance 0.4553
# Rank 3: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0002.jpg with distance 0.4632
# Rank 4: Alejandro_Toledo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alejandro_Toledo\Alejandro_Toledo_0007.jpg with distance 0.4638
# Rank 5: George_Voinovich - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Voinovich\George_Voinovich_0002.jpg with distance 0.4652
# Rank 6: Gloria_Macapagal_Arroyo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gloria_Macapagal_Arroyo\Gloria_Macapagal_Arroyo_0005.jpg with distance 0.4748
# Rank 7: Zoran_Djindjic - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Zoran_Djindjic\Zoran_Djindjic_0001.jpg with distance 0.4776
# Rank 8: Mike_Tyson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Tyson\Mike_Tyson_0003.jpg with distance 0.4780
# Rank 9: Abdullah_Gul - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Abdullah_Gul\Abdullah_Gul_0008.jpg with distance 0.4830
# Rank 10: Kurt_Busch - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kurt_Busch\Kurt_Busch_0001.jpg with distance 0.4831
#
# Top 10 nearest neighbors using dot_product distance:
# Rank 1: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0004.jpg with distance -0.8967
# Rank 2: Gordon_Campbell - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gordon_Campbell\Gordon_Campbell_0001.jpg with distance -0.8964
# Rank 3: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0002.jpg with distance -0.8927
# Rank 4: Alejandro_Toledo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alejandro_Toledo\Alejandro_Toledo_0007.jpg with distance -0.8925
# Rank 5: George_Voinovich - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Voinovich\George_Voinovich_0002.jpg with distance -0.8918
# Rank 6: Gloria_Macapagal_Arroyo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gloria_Macapagal_Arroyo\Gloria_Macapagal_Arroyo_0005.jpg with distance -0.8873
# Rank 7: Zoran_Djindjic - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Zoran_Djindjic\Zoran_Djindjic_0001.jpg with distance -0.8860
# Rank 8: Mike_Tyson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Tyson\Mike_Tyson_0003.jpg with distance -0.8858
# Rank 9: Abdullah_Gul - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Abdullah_Gul\Abdullah_Gul_0008.jpg with distance -0.8834
# Rank 10: Kurt_Busch - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kurt_Busch\Kurt_Busch_0001.jpg with distance -0.8833
#
# Top 10 nearest neighbors using cosine distance:
# Rank 1: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0004.jpg with distance 0.1033
# Rank 2: Gordon_Campbell - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gordon_Campbell\Gordon_Campbell_0001.jpg with distance 0.1036
# Rank 3: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0002.jpg with distance 0.1073
# Rank 4: Alejandro_Toledo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alejandro_Toledo\Alejandro_Toledo_0007.jpg with distance 0.1075
# Rank 5: George_Voinovich - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Voinovich\George_Voinovich_0002.jpg with distance 0.1082
# Rank 6: Gloria_Macapagal_Arroyo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gloria_Macapagal_Arroyo\Gloria_Macapagal_Arroyo_0005.jpg with distance 0.1127
# Rank 7: Zoran_Djindjic - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Zoran_Djindjic\Zoran_Djindjic_0001.jpg with distance 0.1140
# Rank 8: Mike_Tyson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Tyson\Mike_Tyson_0003.jpg with distance 0.1142
# Rank 9: Abdullah_Gul - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Abdullah_Gul\Abdullah_Gul_0008.jpg with distance 0.1166
# Rank 10: Kurt_Busch - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kurt_Busch\Kurt_Busch_0001.jpg with distance 0.1167
#
# Top 10 nearest neighbors using minkowski distance:
# Rank 1: Nancy_Pelosi - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nancy_Pelosi\Nancy_Pelosi_0004.jpg with distance 0.1864
# Rank 2: Gordon_Campbell - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gordon_Campbell\Gordon_Campbell_0001.jpg with distance 0.1871
# Rank 3: George_Voinovich - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Voinovich\George_Voinovich_0002.jpg with distance 0.1893
# Rank 4: Alejandro_Toledo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alejandro_Toledo\Alejandro_Toledo_0007.jpg with distance 0.1896
# Rank 5: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0002.jpg with distance 0.1920
# Rank 6: Mike_Tyson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Tyson\Mike_Tyson_0003.jpg with distance 0.1929
# Rank 7: Gloria_Macapagal_Arroyo - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gloria_Macapagal_Arroyo\Gloria_Macapagal_Arroyo_0005.jpg with distance 0.1942
# Rank 8: Zoran_Djindjic - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Zoran_Djindjic\Zoran_Djindjic_0001.jpg with distance 0.1966
# Rank 9: Kurt_Busch - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kurt_Busch\Kurt_Busch_0001.jpg with distance 0.1989
# Rank 10: Abdullah_Gul - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Abdullah_Gul\Abdullah_Gul_0008.jpg with distance 0.2001
#
# Results for probe image of Owen_Wilson:
#
# Top 10 nearest neighbors using euclidean distance:
# Rank 1: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0001.jpg with distance 0.6134
# Rank 2: Larry_Ellison - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Larry_Ellison\Larry_Ellison_0001.jpg with distance 0.6142
# Rank 3: Dennis_Erickson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dennis_Erickson\Dennis_Erickson_0001.jpg with distance 0.6144
# Rank 4: Kevin_Spacey - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kevin_Spacey\Kevin_Spacey_0001.jpg with distance 0.6166
# Rank 5: Bill_Graham - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Bill_Graham\Bill_Graham_0004.jpg with distance 0.6200
# Rank 6: Martin_Verkerk - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Martin_Verkerk\Martin_Verkerk_0002.jpg with distance 0.6227
# Rank 7: Aleksander_Kwasniewski - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Aleksander_Kwasniewski\Aleksander_Kwasniewski_0003.jpg with distance 0.6261
# Rank 8: Matthew_Perry - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Matthew_Perry\Matthew_Perry_0001.jpg with distance 0.6276
# Rank 9: Eric_Hinske - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Eric_Hinske\Eric_Hinske_0001.jpg with distance 0.6286
# Rank 10: George_Pataki - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Pataki\George_Pataki_0003.jpg with distance 0.6322
#
# Top 10 nearest neighbors using dot_product distance:
# Rank 1: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0001.jpg with distance -0.8119
# Rank 2: Larry_Ellison - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Larry_Ellison\Larry_Ellison_0001.jpg with distance -0.8114
# Rank 3: Dennis_Erickson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dennis_Erickson\Dennis_Erickson_0001.jpg with distance -0.8112
# Rank 4: Kevin_Spacey - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kevin_Spacey\Kevin_Spacey_0001.jpg with distance -0.8099
# Rank 5: Bill_Graham - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Bill_Graham\Bill_Graham_0004.jpg with distance -0.8078
# Rank 6: Martin_Verkerk - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Martin_Verkerk\Martin_Verkerk_0002.jpg with distance -0.8061
# Rank 7: Aleksander_Kwasniewski - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Aleksander_Kwasniewski\Aleksander_Kwasniewski_0003.jpg with distance -0.8040
# Rank 8: Matthew_Perry - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Matthew_Perry\Matthew_Perry_0001.jpg with distance -0.8031
# Rank 9: Eric_Hinske - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Eric_Hinske\Eric_Hinske_0001.jpg with distance -0.8024
# Rank 10: George_Pataki - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Pataki\George_Pataki_0003.jpg with distance -0.8002
#
# Top 10 nearest neighbors using cosine distance:
# Rank 1: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0001.jpg with distance 0.1881
# Rank 2: Larry_Ellison - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Larry_Ellison\Larry_Ellison_0001.jpg with distance 0.1886
# Rank 3: Dennis_Erickson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dennis_Erickson\Dennis_Erickson_0001.jpg with distance 0.1888
# Rank 4: Kevin_Spacey - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kevin_Spacey\Kevin_Spacey_0001.jpg with distance 0.1901
# Rank 5: Bill_Graham - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Bill_Graham\Bill_Graham_0004.jpg with distance 0.1922
# Rank 6: Martin_Verkerk - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Martin_Verkerk\Martin_Verkerk_0002.jpg with distance 0.1939
# Rank 7: Aleksander_Kwasniewski - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Aleksander_Kwasniewski\Aleksander_Kwasniewski_0003.jpg with distance 0.1960
# Rank 8: Matthew_Perry - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Matthew_Perry\Matthew_Perry_0001.jpg with distance 0.1969
# Rank 9: Eric_Hinske - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Eric_Hinske\Eric_Hinske_0001.jpg with distance 0.1976
# Rank 10: George_Pataki - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Pataki\George_Pataki_0003.jpg with distance 0.1998
#
# Top 10 nearest neighbors using minkowski distance:
# Rank 1: Larry_Ellison - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Larry_Ellison\Larry_Ellison_0001.jpg with distance 0.2502
# Rank 2: Bill_Graham - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Bill_Graham\Bill_Graham_0004.jpg with distance 0.2535
# Rank 3: Paul_Bremer - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Paul_Bremer\Paul_Bremer_0001.jpg with distance 0.2544
# Rank 4: Martin_Verkerk - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Martin_Verkerk\Martin_Verkerk_0002.jpg with distance 0.2544
# Rank 5: Kevin_Spacey - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kevin_Spacey\Kevin_Spacey_0001.jpg with distance 0.2546
# Rank 6: Dennis_Erickson - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dennis_Erickson\Dennis_Erickson_0001.jpg with distance 0.2554
# Rank 7: Matthew_Perry - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Matthew_Perry\Matthew_Perry_0001.jpg with distance 0.2558
# Rank 8: Aleksander_Kwasniewski - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Aleksander_Kwasniewski\Aleksander_Kwasniewski_0003.jpg with distance 0.2570
# Rank 9: Bill_Graham - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Bill_Graham\Bill_Graham_0002.jpg with distance 0.2582
# Rank 10: George_Pataki - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Pataki\George_Pataki_0003.jpg with distance 0.2582
#
# Results for probe image of Nelson_Mandela:
#
# Top 10 nearest neighbors using euclidean distance:
# Rank 1: Nelson_Mandela - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nelson_Mandela\Nelson_Mandela_0003.jpg with distance 0.5167
# Rank 2: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0006.jpg with distance 0.5694
# Rank 3: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0006.jpg with distance 0.5835
# Rank 4: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0010.jpg with distance 0.5853
# Rank 5: Ferenc_Madl - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Ferenc_Madl\Ferenc_Madl_0001.jpg with distance 0.6057
# Rank 6: Peter_Struck - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Peter_Struck\Peter_Struck_0001.jpg with distance 0.6104
# Rank 7: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0005.jpg with distance 0.6133
# Rank 8: Boris_Becker - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Boris_Becker\Boris_Becker_0005.jpg with distance 0.6155
# Rank 9: John_Manley - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_Manley\John_Manley_0002.jpg with distance 0.6166
# Rank 10: George_Pataki - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Pataki\George_Pataki_0003.jpg with distance 0.6196
#
# Top 10 nearest neighbors using dot_product distance:
# Rank 1: Nelson_Mandela - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nelson_Mandela\Nelson_Mandela_0003.jpg with distance -0.8665
# Rank 2: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0006.jpg with distance -0.8379
# Rank 3: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0006.jpg with distance -0.8297
# Rank 4: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0010.jpg with distance -0.8287
# Rank 5: Ferenc_Madl - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Ferenc_Madl\Ferenc_Madl_0001.jpg with distance -0.8166
# Rank 6: Peter_Struck - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Peter_Struck\Peter_Struck_0001.jpg with distance -0.8137
# Rank 7: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0005.jpg with distance -0.8119
# Rank 8: Boris_Becker - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Boris_Becker\Boris_Becker_0005.jpg with distance -0.8106
# Rank 9: John_Manley - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_Manley\John_Manley_0002.jpg with distance -0.8099
# Rank 10: George_Pataki - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Pataki\George_Pataki_0003.jpg with distance -0.8081
#
# Top 10 nearest neighbors using cosine distance:
# Rank 1: Nelson_Mandela - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nelson_Mandela\Nelson_Mandela_0003.jpg with distance 0.1335
# Rank 2: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0006.jpg with distance 0.1621
# Rank 3: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0006.jpg with distance 0.1703
# Rank 4: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0010.jpg with distance 0.1713
# Rank 5: Ferenc_Madl - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Ferenc_Madl\Ferenc_Madl_0001.jpg with distance 0.1834
# Rank 6: Peter_Struck - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Peter_Struck\Peter_Struck_0001.jpg with distance 0.1863
# Rank 7: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0005.jpg with distance 0.1881
# Rank 8: Boris_Becker - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Boris_Becker\Boris_Becker_0005.jpg with distance 0.1894
# Rank 9: John_Manley - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_Manley\John_Manley_0002.jpg with distance 0.1901
# Rank 10: George_Pataki - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\George_Pataki\George_Pataki_0003.jpg with distance 0.1919
#
# Top 10 nearest neighbors using minkowski distance:
# Rank 1: Nelson_Mandela - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nelson_Mandela\Nelson_Mandela_0003.jpg with distance 0.2159
# Rank 2: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0006.jpg with distance 0.2320
# Rank 3: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0010.jpg with distance 0.2391
# Rank 4: Dick_Cheney - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Dick_Cheney\Dick_Cheney_0006.jpg with distance 0.2419
# Rank 5: Peter_Struck - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Peter_Struck\Peter_Struck_0001.jpg with distance 0.2481
# Rank 6: Jimmy_Carter - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Jimmy_Carter\Jimmy_Carter_0005.jpg with distance 0.2503
# Rank 7: Ferenc_Madl - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Ferenc_Madl\Ferenc_Madl_0001.jpg with distance 0.2524
# Rank 8: John_Manley - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_Manley\John_Manley_0002.jpg with distance 0.2525
# Rank 9: Boris_Becker - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Boris_Becker\Boris_Becker_0005.jpg with distance 0.2534
# Rank 10: Nelson_Mandela - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Nelson_Mandela\Nelson_Mandela_0001.jpg with distance 0.2547
#
# Results for probe image of Ian_Thorpe:
#
# Top 10 nearest neighbors using euclidean distance:
# Rank 1: Alvaro_Uribe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alvaro_Uribe\Alvaro_Uribe_0005.jpg with distance 0.4894
# Rank 2: Gary_Williams - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gary_Williams\Gary_Williams_0001.jpg with distance 0.5345
# Rank 3: Kim_Ryong-sung - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kim_Ryong-sung\Kim_Ryong-sung_0001.jpg with distance 0.5394
# Rank 4: John_McEnroe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_McEnroe\John_McEnroe_0001.jpg with distance 0.5423
# Rank 5: Michael_Phelps - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Michael_Phelps\Michael_Phelps_0003.jpg with distance 0.5459
# Rank 6: Mikhail_Youzhny - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Youzhny\Mikhail_Youzhny_0002.jpg with distance 0.5524
# Rank 7: Mike_Weir - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Weir\Mike_Weir_0004.jpg with distance 0.5536
# Rank 8: Mikhail_Kasyanov - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Kasyanov\Mikhail_Kasyanov_0003.jpg with distance 0.5544
# Rank 9: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0005.jpg with distance 0.5547
# Rank 10: Meghann_Shaughnessy - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Meghann_Shaughnessy\Meghann_Shaughnessy_0001.jpg with distance 0.5646
#
# Top 10 nearest neighbors using dot_product distance:
# Rank 1: Alvaro_Uribe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alvaro_Uribe\Alvaro_Uribe_0005.jpg with distance -0.8803
# Rank 2: Gary_Williams - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gary_Williams\Gary_Williams_0001.jpg with distance -0.8571
# Rank 3: Kim_Ryong-sung - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kim_Ryong-sung\Kim_Ryong-sung_0001.jpg with distance -0.8545
# Rank 4: John_McEnroe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_McEnroe\John_McEnroe_0001.jpg with distance -0.8530
# Rank 5: Michael_Phelps - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Michael_Phelps\Michael_Phelps_0003.jpg with distance -0.8510
# Rank 6: Mikhail_Youzhny - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Youzhny\Mikhail_Youzhny_0002.jpg with distance -0.8474
# Rank 7: Mike_Weir - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Weir\Mike_Weir_0004.jpg with distance -0.8468
# Rank 8: Mikhail_Kasyanov - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Kasyanov\Mikhail_Kasyanov_0003.jpg with distance -0.8463
# Rank 9: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0005.jpg with distance -0.8462
# Rank 10: Meghann_Shaughnessy - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Meghann_Shaughnessy\Meghann_Shaughnessy_0001.jpg with distance -0.8406
#
# Top 10 nearest neighbors using cosine distance:
# Rank 1: Alvaro_Uribe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alvaro_Uribe\Alvaro_Uribe_0005.jpg with distance 0.1197
# Rank 2: Gary_Williams - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gary_Williams\Gary_Williams_0001.jpg with distance 0.1429
# Rank 3: Kim_Ryong-sung - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kim_Ryong-sung\Kim_Ryong-sung_0001.jpg with distance 0.1455
# Rank 4: John_McEnroe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_McEnroe\John_McEnroe_0001.jpg with distance 0.1470
# Rank 5: Michael_Phelps - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Michael_Phelps\Michael_Phelps_0003.jpg with distance 0.1490
# Rank 6: Mikhail_Youzhny - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Youzhny\Mikhail_Youzhny_0002.jpg with distance 0.1526
# Rank 7: Mike_Weir - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Weir\Mike_Weir_0004.jpg with distance 0.1532
# Rank 8: Mikhail_Kasyanov - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Kasyanov\Mikhail_Kasyanov_0003.jpg with distance 0.1537
# Rank 9: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0005.jpg with distance 0.1538
# Rank 10: Meghann_Shaughnessy - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Meghann_Shaughnessy\Meghann_Shaughnessy_0001.jpg with distance 0.1594
#
# Top 10 nearest neighbors using minkowski distance:
# Rank 1: Alvaro_Uribe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Alvaro_Uribe\Alvaro_Uribe_0005.jpg with distance 0.2024
# Rank 2: Gary_Williams - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Gary_Williams\Gary_Williams_0001.jpg with distance 0.2188
# Rank 3: Kim_Ryong-sung - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Kim_Ryong-sung\Kim_Ryong-sung_0001.jpg with distance 0.2216
# Rank 4: John_McEnroe - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\John_McEnroe\John_McEnroe_0001.jpg with distance 0.2224
# Rank 5: Michael_Phelps - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Michael_Phelps\Michael_Phelps_0003.jpg with distance 0.2240
# Rank 6: Mikhail_Youzhny - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Youzhny\Mikhail_Youzhny_0002.jpg with distance 0.2281
# Rank 7: Mike_Weir - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mike_Weir\Mike_Weir_0004.jpg with distance 0.2282
# Rank 8: Mikhail_Kasyanov - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Mikhail_Kasyanov\Mikhail_Kasyanov_0003.jpg with distance 0.2290
# Rank 9: Geoff_Hoon - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Geoff_Hoon\Geoff_Hoon_0005.jpg with distance 0.2293
# Rank 10: Meghann_Shaughnessy - C:\Users\Putna\OneDrive - Johns Hopkins\Documents\Johns Hopkins\Creating AI Enabled Systems\SP25\ironclad\storage\multi_image_gallery\Meghann_Shaughnessy\Meghann_Shaughnessy_0001.jpg with distance 0.2299

# %% [markdown]
# #### Observations:
# ...place your observations and analysis in this Markdown cell...

# %% [markdown]
# These results offer several interesting insights:
#
# - **Consistency Across Metrics:**
#   For each probe, the ordering of nearest neighbors is remarkably consistent across Euclidean, dot product, cosine, and Minkowski distances. Although the absolute values differ—with Euclidean distances in the range of 0.39–0.63, negative values for dot product, small fractions for cosine, and even lower values for Minkowski—the relative ranking remains stable. This indicates that the embedding space is structured such that different distance measures agree on which images are most similar.
#
# - **Identity Match Variability:**
#   - For **Nelson_Mandela**, the correct gallery image appears at rank 1 across all metrics, suggesting that his facial features are well captured by the model.
#   - In contrast, the probes for **Drew_Barrymore**, **Warren_Buffett**, **Owen_Wilson**, and **Ian_Thorpe** do not have their corresponding identities in the top 10. For example, Drew_Barrymore’s probe is most similar to images of Julie_Gerberding, Geoff_Hoon, and Oscar De La Hoya rather than to another Drew_Barrymore image. This discrepancy might reflect either a limitation in the embedding quality for those particular faces or a lack of variability in the gallery images for those identities.
#
# - **Distance Gaps and Clustering:**
#   The differences between successive ranks (e.g., for Drew_Barrymore, the gap between the top candidate at 0.3953 and the 10th at 0.4317 in Euclidean distance) are relatively small. This narrow range suggests that several gallery images lie within a tight cluster in the embedding space, which could lead to ambiguity when distinguishing among similar faces.
#
# - **Implications for System Performance:**
#   While the embedding space appears to be internally consistent (as evidenced by similar rankings across metrics), the fact that several probe images do not retrieve the correct identity within the top 10 may indicate that further fine-tuning, enhanced preprocessing, or additional data might be necessary to improve discrimination between identities.
#
# Overall, these observations highlight the importance of not only the choice of distance metric—which in this case appears to have a minimal impact on ranking—but also the need to ensure that the embedding model can reliably distinguish among all target identities.

# %% [markdown]
# ---

# %% [markdown]
# #### **Task 3: Assignment Instructions:**
#
# Report the rank positions of the five probe's associated gallery images. Note your observations.

# %%
# Task 3: Report rank positions of the probe's associated gallery images

print("\n--- Rank Positions for Correct Gallery Matches ---\n")
for person, metrics in probe_results.items():
    print(f"Probe Image: {person}")
    for metric, results_list in metrics.items():
        rank_found = None
        # Iterate over the sorted list for the current metric.
        for rank, (dist_val, gallery_entry) in enumerate(results_list, start=1):
            # Check if the gallery image's identity matches the probe's identity.
            if gallery_entry["person"].lower() == person.lower():
                rank_found = rank
                break
        if rank_found is not None:
            print(f"  {metric} distance: Correct gallery image found at rank {rank_found}")
        else:
            print(f"  {metric} distance: No matching gallery image found in the gallery")
    print("-" * 60)
# Out:
# --- Rank Positions for Correct Gallery Matches ---
#
# Probe Image: Drew_Barrymore
#   euclidean distance: Correct gallery image found at rank 360
#   dot_product distance: Correct gallery image found at rank 360
#   cosine distance: Correct gallery image found at rank 360
#   minkowski distance: Correct gallery image found at rank 377
# ------------------------------------------------------------
# Probe Image: Warren_Buffett
#   euclidean distance: Correct gallery image found at rank 521
#   dot_product distance: Correct gallery image found at rank 521
#   cosine distance: Correct gallery image found at rank 521
#   minkowski distance: Correct gallery image found at rank 510
# ------------------------------------------------------------
# Probe Image: Owen_Wilson
#   euclidean distance: Correct gallery image found at rank 437
#   dot_product distance: Correct gallery image found at rank 437
#   cosine distance: Correct gallery image found at rank 437
#   minkowski distance: Correct gallery image found at rank 444
# ------------------------------------------------------------
# Probe Image: Nelson_Mandela
#   euclidean distance: Correct gallery image found at rank 1
#   dot_product distance: Correct gallery image found at rank 1
#   cosine distance: Correct gallery image found at rank 1
#   minkowski distance: Correct gallery image found at rank 1
# ------------------------------------------------------------
# Probe Image: Ian_Thorpe
#   euclidean distance: Correct gallery image found at rank 33
#   dot_product distance: Correct gallery image found at rank 33
#   cosine distance: Correct gallery image found at rank 33
#   minkowski distance: Correct gallery image found at rank 26
# ------------------------------------------------------------

# %% [markdown]
# #### Observations:
# ...place your observations and analysis in this Markdown cell...

# %% [markdown]
# Here are some observations based on the rank positions of the correct gallery matches:
#
# - **Distinctiveness in Embedding Space:**
#   Nelson_Mandela’s probe image is uniquely represented, as his corresponding gallery image is ranked 1 across all metrics. This suggests that his facial features are very distinctive in the embedding space.
#
# - **High Rank Positions for Some Identities:**
#   For Drew_Barrymore, Warren_Buffett, and Owen_Wilson, the correct gallery image appears very far down the sorted list (ranks 360, 521, and 437, respectively). This indicates that many other gallery images are deemed more similar than the true match, which might reflect overlapping features or a lack of distinctiveness for these individuals.
#
# - **Metric Consistency:**
#   The rank positions are nearly identical across Euclidean, dot product, and cosine distances, with only minor variations for Minkowski. This consistency reinforces that the embedding space is structured similarly regardless of the distance measure used.
#
# - **Intermediate Performance for Ian_Thorpe:**
#   Ian_Thorpe’s correct match appears at a relatively lower rank (rank 33 for most metrics and rank 26 for Minkowski), suggesting a better match compared to Drew_Barrymore, Warren_Buffett, and Owen_Wilson, yet not as distinct as Nelson_Mandela.
#
# - **Implications for System Tuning:**
#   The large rank differences for certain identities imply that further fine-tuning of the embedding model, preprocessing steps, or even augmenting the gallery data might be necessary to improve discrimination—especially for those identities with very high rank positions.
#
# Overall, while the embedding space shows consistency across different distance metrics, the variation in rank positions highlights that some identities are much better captured than others, pointing to potential areas for improvement in the system.
