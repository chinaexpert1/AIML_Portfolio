# %% [markdown]
# # EDA notebook

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# Exploratory Data Analysis for Fraud Detection\n",
#       8     "\n",
#       9     "In this notebook, we extract and transform our raw data using the `RawDataHandler` class. We then explore the resulting dataset to identify features that strongly predict the binary variable `fraud_label`."
#      10    ]
#      11   },
#      12   {
#      13    "cell_type": "code",
# ---> 14    "execution_count": null,
#      15    "metadata": {},
#      16    "outputs": [],
#      17    "source": [
#      18     "import os\n",
#      19     "import pandas as pd\n",
#      20     "import numpy as np\n",
#      21     "import matplotlib.pyplot as plt\n",
# ...
