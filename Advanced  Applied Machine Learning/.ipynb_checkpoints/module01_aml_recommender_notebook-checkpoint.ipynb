# %% [markdown]
# © Guven
#
# # Recommender Systems<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Recommender-Systems"
# class="anchor-link">¶</a>
#
# ## Introduction<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Introduction"
# class="anchor-link">¶</a>
#
#     "Example is not the main thing in influencing others. It is the only thing." Albert Schweitzer
#
# Today, we regularly interact with recommender systems using digital
# services and applications, from online retailers to movie and TV
# services and news aggregators. These are algorithms that make
# suggestions about what a user may like, such as a specific movie. They
# are functions that take information about a user's preferences as input
# to generate a prediction about the rating a user would give of the items
# under evaluation and predict how they would rank a set of items
# individually or as a bundle. Recommender systems collect, curate, and
# act upon vast personal data. Inevitably, they shape individual
# experiences of digital environments and social interactions.
#
# The basic principle of recommendation methods is based on the assumption
# (or fact?) that significant dependencies exist between the user and the
# items. For example, a user interested in a historical Second World War
# documentary is more likely to be interested in another historical
# documentary or an educational program rather than an action movie. In
# many cases, various categories of items may show significant
# correlations, which can be leveraged to make more accurate
# recommendations based on this similarity.
#
# Alternatively, the dependencies may be present at the finer granularity
# of individual items rather than categories. These dependencies can be
# learned in a data-driven approach from the ratings matrix, and the
# resulting model is used to make predictions for target users. The larger
# the number of rated items that are available for a user, the easier it
# is to make robust predictions about the future behavior of the user. A
# variety of learning models can be used to accomplish this task. For
# example, the collective buying or rating behavior of various users can
# be leveraged to create cohorts of similar users interested in similar
# products. The interests and actions of these cohorts can be leveraged to
# make recommendations to individual members of these cohorts.
#
# These above approaches can be referred to as neighborhood models or
# referred to as collaborative filtering. The term *collaborative
# filtering* refers to the use of ratings from multiple users in a
# collaborative way to predict missing ratings. In practice, recommender
# systems can be more complex and data-enriched. For example, in
# content-based recommender systems, the content plays a primary role in
# the recommendation process, in which the ratings of users and the
# attribute descriptions of items are leveraged to make predictions. The
# basic idea is that user interests can be modeled based on properties (or
# attributes) of the items they have rated or accessed in the past. A
# different framework is knowledge-based systems, in which users
# interactively specify their interests, and the user specification is
# combined with domain knowledge to provide recommendations. In advanced
# models, contextual data, such as temporal information, external
# knowledge, location information, social information, or network
# information, can also be used.
#
# In this module, we will build a recommender system on the MovieLens
# dataset, which is composed of five sub-datasets of (1.) movies, (2.)
# movie ratings, (3.) movie tags, (4.) tags to describe movies by users,
# and (5.) movie tag scores.
#
# ## Distance/Similarity Measures<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Distance/Similarity-Measures"
# class="anchor-link">¶</a>
#
# A distance metric, <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-1-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo&gt;:&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;bold&quot;&gt;X&lt;/mi&gt;&lt;/mrow&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;bold&quot;&gt;X&lt;/mi&gt;&lt;/mrow&gt;&lt;mo stretchy=&quot;false&quot;&gt;&amp;#x27F6;&lt;/mo&gt;&lt;mo stretchy=&quot;false&quot;&gt;[&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x221E;&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msup&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;R&lt;/mi&gt;&lt;/mrow&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-1"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-2"
# class="mjx-mrow"><span id="MJXc-Node-3"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-4"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.124em; padding-bottom: 0.366em;">:</span></span><span id="MJXc-Node-5"
# class="mjx-texatom MJXc-space3"><span id="MJXc-Node-6"
# class="mjx-mrow"><span id="MJXc-Node-7"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-B"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">X</span></span></span></span><span id="MJXc-Node-8"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-9"
# class="mjx-texatom MJXc-space2"><span id="MJXc-Node-10"
# class="mjx-mrow"><span id="MJXc-Node-11"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-B"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">X</span></span></span></span><span id="MJXc-Node-12"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">⟶</span></span><span id="MJXc-Node-13"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">\[</span></span><span id="MJXc-Node-14"
# class="mjx-mn"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">0</span></span><span id="MJXc-Node-15"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-16"
# class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.366em;">∞</span></span><span id="MJXc-Node-17"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">)</span></span><span id="MJXc-Node-18"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-19"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-20"
# class="mjx-texatom"><span id="MJXc-Node-21"
# class="mjx-mrow"><span id="MJXc-Node-22"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">R</span></span></span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.615em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-23"
# class="mjx-mo" style=""><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.306em; padding-bottom: 0.427em;">+</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$d:\mathbf{X} \times \mathbf{X}\longrightarrow\lbrack 0,\infty) \in \mathbb{R}^{+}$</span></span>$d:\mathbf{X} \times \mathbf{X} \longrightarrow [0,\infty) \in \mathbb{R}^+$,
# satisfies the following:
#
# | Property | Name |
# |:---|:---|
# | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-2-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-24" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-25" class="mjx-mrow"><span id="MJXc-Node-26" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-27" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-28" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span><span id="MJXc-Node-29" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="margin-top: -0.196em; padding-bottom: 0.534em;">,</span></span><span id="MJXc-Node-30" class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em; padding-right: 0.006em;">y</span></span><span id="MJXc-Node-31" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span><span id="MJXc-Node-32" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.468em;">≥</span></span><span id="MJXc-Node-33" class="mjx-mn MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">0</span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d(x,y) \geq 0$</span></span>$d(x,y)\ge 0$ | non-negative |
# | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-3-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;mspace width=&quot;thickmathspace&quot; /&gt;&lt;mo stretchy=&quot;false&quot;&gt;&amp;#x27FA;&lt;/mo&gt;&lt;mspace width=&quot;thickmathspace&quot; /&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-34" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-35" class="mjx-mrow"><span id="MJXc-Node-36" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-37" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-38" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span><span id="MJXc-Node-39" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="margin-top: -0.196em; padding-bottom: 0.534em;">,</span></span><span id="MJXc-Node-40" class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em; padding-right: 0.006em;">y</span></span><span id="MJXc-Node-41" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span><span id="MJXc-Node-42" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-43" class="mjx-mn MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">0</span></span><span id="MJXc-Node-44" class="mjx-mspace" style="width: 0.278em; height: 0px;"></span><span id="MJXc-Node-45" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.335em;">⟺</span></span><span id="MJXc-Node-46" class="mjx-mspace" style="width: 0.278em; height: 0px;"></span><span id="MJXc-Node-47" class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span><span id="MJXc-Node-48" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-49" class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em; padding-right: 0.006em;">y</span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d(x,y) = 0\;\Longleftrightarrow\; x = y$</span></span>$d(x,y)=0 \iff x=y$ | identity |
# | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-4-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-50" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-51" class="mjx-mrow"><span id="MJXc-Node-52" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-53" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-54" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span><span id="MJXc-Node-55" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="margin-top: -0.196em; padding-bottom: 0.534em;">,</span></span><span id="MJXc-Node-56" class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em; padding-right: 0.006em;">y</span></span><span id="MJXc-Node-57" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span><span id="MJXc-Node-58" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-59" class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-60" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-61" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em; padding-right: 0.006em;">y</span></span><span id="MJXc-Node-62" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="margin-top: -0.196em; padding-bottom: 0.534em;">,</span></span><span id="MJXc-Node-63" class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span><span id="MJXc-Node-64" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d(x,y) = d(y,x)$</span></span>$d(x,y)=d(y,x)$ | symmetry |
# | <span class="MathJax_Preview" style="color: inherit;"></span><span class="mjx-chtml MJXc-display" style="text-align: center;"><span id="MathJax-Element-5-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo&gt;&amp;#x2264;&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;y&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; text-align: center; position: relative;"><span id="MJXc-Node-65" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-66" class="mjx-mrow"><span id="MJXc-Node-67" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-68" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-69" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span><span id="MJXc-Node-70" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="margin-top: -0.196em; padding-bottom: 0.534em;">,</span></span><span id="MJXc-Node-71" class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em; padding-right: 0.006em;">y</span></span><span id="MJXc-Node-72" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span><span id="MJXc-Node-73" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.468em;">≤</span></span><span id="MJXc-Node-74" class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-75" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-76" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span><span id="MJXc-Node-77" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="margin-top: -0.196em; padding-bottom: 0.534em;">,</span></span><span id="MJXc-Node-78" class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em; padding-right: 0.003em;">z</span></span><span id="MJXc-Node-79" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span><span id="MJXc-Node-80" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">+</span></span><span id="MJXc-Node-81" class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span><span id="MJXc-Node-82" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-83" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em; padding-right: 0.003em;">z</span></span><span id="MJXc-Node-84" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="margin-top: -0.196em; padding-bottom: 0.534em;">,</span></span><span id="MJXc-Node-85" class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em; padding-right: 0.006em;">y</span></span><span id="MJXc-Node-86" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span></span></span><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation">$$d(x,y) \leq d(x,z) + d(z,y)$$</span></span></span>$$d(x,y)\le d(x,z)+d(z,y)$$ | triangle inequality |
#
# Define <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-6-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-87"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-88"
# class="mjx-mrow"><span id="MJXc-Node-89"
# class="mjx-msubsup"><span class="mjx-base"
# style="margin-right: -0.003em;"><span id="MJXc-Node-90"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.003em;">d</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-91"
# class="mjx-texatom" style=""><span id="MJXc-Node-92"
# class="mjx-mrow"><span id="MJXc-Node-93"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span><span id="MJXc-Node-94"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.487em;">j</span></span></span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$d_{ij}$</span></span>$d_{ij}$ = the distance
# between the user <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-7-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-95"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-96"
# class="mjx-mrow"><span id="MJXc-Node-97"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$i$</span></span>$i$ and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-8-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-98"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-99"
# class="mjx-mrow"><span id="MJXc-Node-100"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.487em;">j</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$j$</span></span>$j$, where there are
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-9-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-101"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-102"
# class="mjx-mrow"><span id="MJXc-Node-103"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$N$</span></span>$N$ users,
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-10-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-104"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-105"
# class="mjx-mrow"><span id="MJXc-Node-106"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$M$</span></span>$M$ movies, and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-11-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;bold&quot;&gt;X&lt;/mi&gt;&lt;/mrow&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-107"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-108"
# class="mjx-mrow"><span id="MJXc-Node-109"
# class="mjx-texatom"><span id="MJXc-Node-110"
# class="mjx-mrow"><span id="MJXc-Node-111"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-B"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">X</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$\mathbf{X}$</span></span>$\mathbf{X}$ as the movie
# ratings of users as <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-12-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msup&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;R&lt;/mi&gt;&lt;/mrow&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mtext mathvariant=&quot;monospace&quot;&gt;x&lt;/mtext&gt;&lt;/mrow&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-112"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-113"
# class="mjx-mrow"><span id="MJXc-Node-114"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">x</span></span><span id="MJXc-Node-115"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-116"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-117"
# class="mjx-texatom"><span id="MJXc-Node-118"
# class="mjx-mrow"><span id="MJXc-Node-119"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">R</span></span></span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.615em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-120"
# class="mjx-texatom" style=""><span id="MJXc-Node-121"
# class="mjx-mrow"><span id="MJXc-Node-122"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span><span id="MJXc-Node-123"
# class="mjx-texatom"><span id="MJXc-Node-124"
# class="mjx-mrow"><span id="MJXc-Node-125"
# class="mjx-mtext"><span class="mjx-char MJXc-TeX-type-R"
# style="padding-top: 0.245em; padding-bottom: 0.245em;">x</span></span></span></span><span id="MJXc-Node-126"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span></span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$x \in \mathbb{R}^{N\texttt{x}M}$</span></span>$x\in \mathbb{R}^{N\texttt{x}M}$.
# Define <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-13-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-127"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-128"
# class="mjx-mrow"><span id="MJXc-Node-129"
# class="mjx-msubsup"><span class="mjx-base"
# style="margin-right: -0.064em;"><span id="MJXc-Node-130"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-131"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$I_{i}$</span></span>$I_i$ as the set of movies user
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-14-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-132"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-133"
# class="mjx-mrow"><span id="MJXc-Node-134"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$i$</span></span>$i$ rated, where
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-15-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;{&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;}&lt;/mo&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-135"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-136"
# class="mjx-mrow"><span id="MJXc-Node-137"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span><span id="MJXc-Node-138"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-139"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">{</span></span><span id="MJXc-Node-140"
# class="mjx-mn"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">1</span></span><span id="MJXc-Node-141"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-142"
# class="mjx-mn MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">2</span></span><span id="MJXc-Node-143"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-144"
# class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.366em;">…</span></span><span id="MJXc-Node-145"
# class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-146"
# class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span><span id="MJXc-Node-147"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">}</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$i \in \{ 1,2,\ldots,N\}$</span></span>$i \in \{1,2,\dots,N\}$
# and <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-16-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;P&lt;/mi&gt;&lt;/mrow&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;{&lt;/mo&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mo&gt;&amp;#x2026;&lt;/mo&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;}&lt;/mo&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-148"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-149"
# class="mjx-mrow"><span id="MJXc-Node-150"
# class="mjx-msubsup"><span class="mjx-base"
# style="margin-right: -0.064em;"><span id="MJXc-Node-151"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-152"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span></span></span><span id="MJXc-Node-153"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-154"
# class="mjx-texatom MJXc-space3"><span id="MJXc-Node-155"
# class="mjx-mrow"><span id="MJXc-Node-156"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">P</span></span></span></span><span id="MJXc-Node-157"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">(</span></span><span id="MJXc-Node-158"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">{</span></span><span id="MJXc-Node-159"
# class="mjx-mn"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">1</span></span><span id="MJXc-Node-160"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-161"
# class="mjx-mn MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">2</span></span><span id="MJXc-Node-162"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-163"
# class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.366em;">…</span></span><span id="MJXc-Node-164"
# class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-165"
# class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span><span id="MJXc-Node-166"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">}</span></span><span id="MJXc-Node-167"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">)</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$I_{i} \in \mathbb{P}(\{ 1,2,\ldots,M\})$</span></span>$I_i \in \mathbb{P}(\{1,2,\dots,M\})$.
#
# | Name | Distance |
# |:---|:---|
# | Jaccard index | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-17-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mstyle displaystyle=&quot;true&quot; scriptlevel=&quot;0&quot;&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2229;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x222A;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;/mstyle&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-168" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-169" class="mjx-mrow"><span id="MJXc-Node-170" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.003em;"><span id="MJXc-Node-171" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-172" class="mjx-texatom" style=""><span id="MJXc-Node-173" class="mjx-mrow"><span id="MJXc-Node-174" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-175" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span id="MJXc-Node-176" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-177" class="mjx-mstyle MJXc-space3"><span id="MJXc-Node-178" class="mjx-mrow"><span id="MJXc-Node-179" class="mjx-mfrac"><span class="mjx-box MJXc-stacked" style="width: 3.061em; padding: 0px 0.12em;"><span class="mjx-numerator" style="width: 3.061em; top: -1.452em;"><span id="MJXc-Node-180" class="mjx-mrow"><span id="MJXc-Node-181" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-182" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-183" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-184" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∩</span></span><span id="MJXc-Node-185" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-186" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-187" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span class="mjx-denominator" style="width: 3.061em; bottom: -0.998em;"><span id="MJXc-Node-188" class="mjx-mrow"><span id="MJXc-Node-189" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-190" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-191" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-192" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∪</span></span><span id="MJXc-Node-193" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-194" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-195" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span class="mjx-line" style="border-bottom: 1.3px solid; top: -0.291em; width: 3.061em;"></span></span><span class="mjx-vsize" style="height: 2.45em; vertical-align: -0.998em;"></span></span></span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d_{ij} = \frac{x_{i} \cap x_{j}}{x_{i} \cup x_{j}}$</span></span>$d_{ij}= \dfrac{x_i \cap x_j}{x_i \cup x_j}$ |
# | Cosine <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-18-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;&amp;#x03B8;&lt;/mi&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-196" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-197" class="mjx-mrow"><span id="MJXc-Node-198" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">θ</span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$\theta$</span></span>$\theta$ | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-19-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;cos&lt;/mi&gt;&lt;mo&gt;&amp;#x2061;&lt;/mo&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;&amp;#x03B8;&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mstyle displaystyle=&quot;true&quot; scriptlevel=&quot;0&quot;&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;/mstyle&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-199" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-200" class="mjx-mrow"><span id="MJXc-Node-201" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.003em;"><span id="MJXc-Node-202" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-203" class="mjx-texatom" style=""><span id="MJXc-Node-204" class="mjx-mrow"><span id="MJXc-Node-205" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-206" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span id="MJXc-Node-207" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-208" class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.136em; padding-bottom: 0.335em;">cos</span></span><span id="MJXc-Node-209" class="mjx-mo"><span class="mjx-char"></span></span><span id="MJXc-Node-210" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-211" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">θ</span></span><span id="MJXc-Node-212" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span><span id="MJXc-Node-213" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-214" class="mjx-mstyle MJXc-space3"><span id="MJXc-Node-215" class="mjx-mrow"><span id="MJXc-Node-216" class="mjx-mfrac"><span class="mjx-box MJXc-stacked" style="width: 3.95em; padding: 0px 0.12em;"><span class="mjx-numerator" style="width: 3.95em; top: -1.296em;"><span id="MJXc-Node-217" class="mjx-mrow"><span id="MJXc-Node-218" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-219" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-220" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-221" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.003em; padding-bottom: 0.335em;">⋅</span></span><span id="MJXc-Node-222" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-223" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-224" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span class="mjx-denominator" style="width: 3.95em; bottom: -1.104em;"><span id="MJXc-Node-225" class="mjx-mrow"><span id="MJXc-Node-226" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span><span id="MJXc-Node-227" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-228" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-229" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-230" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span><span id="MJXc-Node-231" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span><span id="MJXc-Node-232" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-233" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-234" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span><span id="MJXc-Node-235" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span></span></span><span class="mjx-line" style="border-bottom: 1.3px solid; top: -0.291em; width: 3.95em;"></span></span><span class="mjx-vsize" style="height: 2.4em; vertical-align: -1.104em;"></span></span></span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d_{ij} = \cos(\theta) = \frac{x_{i} \cdot x_{j}}{\| x_{i}\|\| x_{j}\|}$</span></span>$d_{ij}=\cos(\theta)=\dfrac{x_i \cdot x_j}{\|x_i\| \|x_j\|}$ |
# | Pearson | <span class="MathJax_Preview" style="color: inherit;"></span><span class="mjx-chtml MJXc-display" style="text-align: center;"><span id="MathJax-Element-20-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot; display=&quot;block&quot;&gt;&lt;msub&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mfrac&gt;&lt;mrow&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2229;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;&amp;#x03BC;&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;&amp;#x03BC;&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;/mrow&gt;&lt;mrow&gt;&lt;msqrt&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2229;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;&amp;#x03BC;&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;msup&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/msqrt&gt;&lt;msqrt&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2229;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;&amp;#x03BC;&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;msup&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/msqrt&gt;&lt;/mrow&gt;&lt;/mfrac&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; text-align: center; position: relative;"><span id="MJXc-Node-236" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-237" class="mjx-mrow"><span id="MJXc-Node-238" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.003em;"><span id="MJXc-Node-239" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-240" class="mjx-texatom" style=""><span id="MJXc-Node-241" class="mjx-mrow"><span id="MJXc-Node-242" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-243" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span id="MJXc-Node-244" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-245" class="mjx-mfrac MJXc-space3"><span class="mjx-box MJXc-stacked" style="width: 18.237em; padding: 0px 0.12em;"><span class="mjx-numerator" style="width: 18.237em; top: -1.838em;"><span id="MJXc-Node-246" class="mjx-mrow"><span id="MJXc-Node-247" class="mjx-munderover"><span class="mjx-base"><span id="MJXc-Node-248" class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R" style="padding-top: 0.534em; padding-bottom: 0.534em;">∑</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.439em; padding-right: 0.071em;"><span id="MJXc-Node-249" class="mjx-texatom" style=""><span id="MJXc-Node-250" class="mjx-mrow"><span id="MJXc-Node-251" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span><span id="MJXc-Node-252" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">∈</span></span><span id="MJXc-Node-253" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-254" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-255" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-256" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∩</span></span><span id="MJXc-Node-257" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-258" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-259" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span></span></span><span id="MJXc-Node-260" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-261" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-262" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-263" class="mjx-texatom" style=""><span id="MJXc-Node-264" class="mjx-mrow"><span id="MJXc-Node-265" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-266" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-267" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">−</span></span><span id="MJXc-Node-268" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-269" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em;">μ</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-270" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-271" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span><span id="MJXc-Node-272" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-273" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-274" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-275" class="mjx-texatom" style=""><span id="MJXc-Node-276" class="mjx-mrow"><span id="MJXc-Node-277" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span><span id="MJXc-Node-278" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-279" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">−</span></span><span id="MJXc-Node-280" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-281" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em;">μ</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-282" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span><span id="MJXc-Node-283" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span></span></span><span class="mjx-denominator" style="width: 18.237em; bottom: -1.927em;"><span id="MJXc-Node-284" class="mjx-mrow"><span id="MJXc-Node-285" class="mjx-msqrt"><span class="mjx-box" style="padding-top: 0.045em;"><span class="mjx-surd"><span class="mjx-char MJXc-TeX-size2-R" style="padding-top: 0.932em; padding-bottom: 0.932em;">√</span></span><span class="mjx-box" style="padding-top: 0.226em; border-top: 1.1px solid;"><span id="MJXc-Node-286" class="mjx-mrow"><span id="MJXc-Node-287" class="mjx-munderover"><span class="mjx-base"><span id="MJXc-Node-288" class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R" style="padding-top: 0.534em; padding-bottom: 0.534em;">∑</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.439em; padding-right: 0.071em;"><span id="MJXc-Node-289" class="mjx-texatom" style=""><span id="MJXc-Node-290" class="mjx-mrow"><span id="MJXc-Node-291" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span><span id="MJXc-Node-292" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">∈</span></span><span id="MJXc-Node-293" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-294" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-295" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-296" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∩</span></span><span id="MJXc-Node-297" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-298" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-299" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span></span></span><span id="MJXc-Node-300" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-301" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-302" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-303" class="mjx-texatom" style=""><span id="MJXc-Node-304" class="mjx-mrow"><span id="MJXc-Node-305" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-306" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-307" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">−</span></span><span id="MJXc-Node-308" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-309" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em;">μ</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-310" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-311" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-312" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span></span><span class="mjx-sup" style="font-size: 70.7%; vertical-align: 0.409em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-313" class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span></span></span><span id="MJXc-Node-314" class="mjx-msqrt"><span class="mjx-box" style="padding-top: 0.045em;"><span class="mjx-surd"><span class="mjx-char MJXc-TeX-size2-R" style="padding-top: 0.932em; padding-bottom: 0.932em;">√</span></span><span class="mjx-box" style="padding-top: 0.226em; border-top: 1.1px solid;"><span id="MJXc-Node-315" class="mjx-mrow"><span id="MJXc-Node-316" class="mjx-munderover"><span class="mjx-base"><span id="MJXc-Node-317" class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R" style="padding-top: 0.534em; padding-bottom: 0.534em;">∑</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.439em; padding-right: 0.071em;"><span id="MJXc-Node-318" class="mjx-texatom" style=""><span id="MJXc-Node-319" class="mjx-mrow"><span id="MJXc-Node-320" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span><span id="MJXc-Node-321" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">∈</span></span><span id="MJXc-Node-322" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-323" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-324" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-325" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∩</span></span><span id="MJXc-Node-326" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-327" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-328" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span></span></span><span id="MJXc-Node-329" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-330" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-331" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-332" class="mjx-texatom" style=""><span id="MJXc-Node-333" class="mjx-mrow"><span id="MJXc-Node-334" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span><span id="MJXc-Node-335" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-336" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">−</span></span><span id="MJXc-Node-337" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-338" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.468em;">μ</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-339" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span><span id="MJXc-Node-340" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-341" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span></span><span class="mjx-sup" style="font-size: 70.7%; vertical-align: 0.409em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-342" class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span></span></span></span></span><span class="mjx-line" style="border-bottom: 1.3px solid; top: -0.291em; width: 18.237em;"></span></span><span class="mjx-vsize" style="height: 3.765em; vertical-align: -1.927em;"></span></span></span></span><span class="MJX_Assistive_MathML MJX_Assistive_MathML_Block" role="presentation">$$d_{ij} = \frac{\sum\limits_{k \in I_{i} \cap I_{j}}(x_{ik} - \mu_{i})(x_{jk} - \mu_{j})}{\sqrt{\sum\limits_{k \in I_{i} \cap I_{j}}(x_{ik} - \mu_{i})^{2}}\sqrt{\sum\limits_{k \in I_{i} \cap I_{j}}(x_{jk} - \mu_{j})^{2}}}$$</span></span></span>$$d_{ij}= \frac {\sum_{k \in I_i \cap I_j} (x_{ik}-\mu_i)(x_{jk}-\mu_j)} {\sqrt{\sum_{k \in I_i \cap I_j} (x_{ik}-\mu_i)^2}\sqrt{\sum_{k \in I_i \cap I_j} (x_{jk}-\mu_j)^2}} $$ |
# | Manhattan, <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-21-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mtext&gt;L&lt;/mtext&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-343" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-344" class="mjx-mrow"><span id="MJXc-Node-345" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-346" class="mjx-mtext"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">L</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-347" class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">1</span></span></span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$\text{L}_{1}$</span></span>$\text{L}_1$ | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-22-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2229;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;/mrow&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-348" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-349" class="mjx-mrow"><span id="MJXc-Node-350" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.003em;"><span id="MJXc-Node-351" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-352" class="mjx-texatom" style=""><span id="MJXc-Node-353" class="mjx-mrow"><span id="MJXc-Node-354" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-355" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span id="MJXc-Node-356" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-357" class="mjx-munderover MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-358" class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R" style="padding-top: 0.534em; padding-bottom: 0.534em;">∑</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.439em; padding-right: 0.071em;"><span id="MJXc-Node-359" class="mjx-texatom" style=""><span id="MJXc-Node-360" class="mjx-mrow"><span id="MJXc-Node-361" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span><span id="MJXc-Node-362" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">∈</span></span><span id="MJXc-Node-363" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-364" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-365" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-366" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∩</span></span><span id="MJXc-Node-367" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-368" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-369" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span></span></span><span id="MJXc-Node-370" class="mjx-texatom MJXc-space1"><span id="MJXc-Node-371" class="mjx-mrow"><span id="MJXc-Node-372" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span><span id="MJXc-Node-373" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-374" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-375" class="mjx-texatom" style=""><span id="MJXc-Node-376" class="mjx-mrow"><span id="MJXc-Node-377" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-378" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-379" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">−</span></span><span id="MJXc-Node-380" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-381" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-382" class="mjx-texatom" style=""><span id="MJXc-Node-383" class="mjx-mrow"><span id="MJXc-Node-384" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span><span id="MJXc-Node-385" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-386" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span></span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d_{ij} = \sum\limits_{k \in I_{i} \cap I_{j}}{\| x_{ik} - x_{jk}\|}$</span></span>$d_{ij}=\sum_{k\in I_i \cap I_j}{\|x_{ik}-x_{jk}\|}$ |
# | Euclidean, <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-23-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mtext&gt;L&lt;/mtext&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-387" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-388" class="mjx-mrow"><span id="MJXc-Node-389" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-390" class="mjx-mtext"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">L</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-391" class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$\text{L}_{2}$</span></span>$\text{L}_2$ | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-24-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msqrt&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2229;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;msup&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/msqrt&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-392" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-393" class="mjx-mrow"><span id="MJXc-Node-394" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.003em;"><span id="MJXc-Node-395" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-396" class="mjx-texatom" style=""><span id="MJXc-Node-397" class="mjx-mrow"><span id="MJXc-Node-398" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-399" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span id="MJXc-Node-400" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-401" class="mjx-msqrt MJXc-space3"><span class="mjx-box" style="padding-top: 0.045em;"><span class="mjx-surd"><span class="mjx-char MJXc-TeX-size2-R" style="padding-top: 0.932em; padding-bottom: 0.932em;">√</span></span><span class="mjx-box" style="padding-top: 0.226em; border-top: 1.1px solid;"><span id="MJXc-Node-402" class="mjx-mrow"><span id="MJXc-Node-403" class="mjx-munderover"><span class="mjx-base"><span id="MJXc-Node-404" class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R" style="padding-top: 0.534em; padding-bottom: 0.534em;">∑</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.439em; padding-right: 0.071em;"><span id="MJXc-Node-405" class="mjx-texatom" style=""><span id="MJXc-Node-406" class="mjx-mrow"><span id="MJXc-Node-407" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span><span id="MJXc-Node-408" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">∈</span></span><span id="MJXc-Node-409" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-410" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-411" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-412" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∩</span></span><span id="MJXc-Node-413" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-414" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-415" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span></span></span><span id="MJXc-Node-416" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">(</span></span><span id="MJXc-Node-417" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-418" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-419" class="mjx-texatom" style=""><span id="MJXc-Node-420" class="mjx-mrow"><span id="MJXc-Node-421" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-422" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-423" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">−</span></span><span id="MJXc-Node-424" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-425" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-426" class="mjx-texatom" style=""><span id="MJXc-Node-427" class="mjx-mrow"><span id="MJXc-Node-428" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span><span id="MJXc-Node-429" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-430" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-431" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">)</span></span></span><span class="mjx-sup" style="font-size: 70.7%; vertical-align: 0.409em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-432" class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span></span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d_{ij} = \sqrt{\sum\limits_{k \in I_{i} \cap I_{j}}(x_{ik} - x_{jk})^{2}}$</span></span>$d_{ij}=\sqrt{\sum_{k \in I_i \cap I_j} (x_{ik}-x_{jk})^2}$ |
# | Chebyshev | <span class="MathJax_Preview" style="color: inherit;"></span><span id="MathJax-Element-25-Frame" class="mjx-chtml MathJax_CHTML" tabindex="0" mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;d&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;munder&gt;&lt;mo movablelimits=&quot;true&quot; form=&quot;prefix&quot;&gt;max&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2229;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;I&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/msub&gt;&lt;/mrow&gt;&lt;/munder&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;/math&gt;" role="presentation" style="font-size: 116%; position: relative;"><span id="MJXc-Node-433" class="mjx-math" aria-hidden="true"><span id="MJXc-Node-434" class="mjx-mrow"><span id="MJXc-Node-435" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.003em;"><span id="MJXc-Node-436" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.003em;">d</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-437" class="mjx-texatom" style=""><span id="MJXc-Node-438" class="mjx-mrow"><span id="MJXc-Node-439" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-440" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span><span id="MJXc-Node-441" class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.07em; padding-bottom: 0.335em;">=</span></span><span id="MJXc-Node-442" class="mjx-munderover MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-443" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.136em; padding-bottom: 0.335em;">max</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-444" class="mjx-texatom" style=""><span id="MJXc-Node-445" class="mjx-mrow"><span id="MJXc-Node-446" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span><span id="MJXc-Node-447" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">∈</span></span><span id="MJXc-Node-448" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-449" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-450" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span></span></span><span id="MJXc-Node-451" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.335em; padding-bottom: 0.335em;">∩</span></span><span id="MJXc-Node-452" class="mjx-msubsup"><span class="mjx-base" style="margin-right: -0.064em;"><span id="MJXc-Node-453" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em; padding-right: 0.064em;">I</span></span></span><span class="mjx-sub" style="font-size: 75%; vertical-align: -0.215em; padding-right: 0.067em;"><span id="MJXc-Node-454" class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span></span></span></span></span></span></span><span id="MJXc-Node-455" class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span><span id="MJXc-Node-456" class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-457" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-458" class="mjx-texatom" style=""><span id="MJXc-Node-459" class="mjx-mrow"><span id="MJXc-Node-460" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">i</span></span><span id="MJXc-Node-461" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-462" class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.269em; padding-bottom: 0.401em;">−</span></span><span id="MJXc-Node-463" class="mjx-msubsup MJXc-space2"><span class="mjx-base"><span id="MJXc-Node-464" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.202em; padding-bottom: 0.269em;">x</span></span></span><span class="mjx-sub" style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-465" class="mjx-texatom" style=""><span id="MJXc-Node-466" class="mjx-mrow"><span id="MJXc-Node-467" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.468em;">j</span></span><span id="MJXc-Node-468" class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I" style="padding-top: 0.468em; padding-bottom: 0.269em;">k</span></span></span></span></span></span><span id="MJXc-Node-469" class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R" style="padding-top: 0.468em; padding-bottom: 0.6em;">∥</span></span></span></span><span class="MJX_Assistive_MathML" role="presentation">$d_{ij} = \max\limits_{k \in I_{i} \cap I_{j}}\| x_{ik} - x_{jk}\|$</span></span>$d_{ij}= \max_{k \in I_i \cap I_j} \|x_{ik}-x_{jk}\|$ |
#
# The following table can be used as a guideline to apply distance
# metrics.
#
# <table>
# <colgroup>
# <col style="width: 33%" />
# <col style="width: 33%" />
# <col style="width: 33%" />
# </colgroup>
# <thead>
# <tr>
# <th style="text-align: left;">Data</th>
# <th style="text-align: left;">Example</th>
# <th style="text-align: left;">Similarity</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align: left;">Unary<br />
# (only <span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-26-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x2661;&lt;/mi&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-470" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-471" class="mjx-mrow"><span id="MJXc-Node-472"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.401em;">♡</span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline">♡</span></span></span><span
# class="math inline">♡</span>)<br />
# Transactions of movies liked</td>
# <td style="text-align: left;">u<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-27-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-473" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-474" class="mjx-mrow"><span id="MJXc-Node-475"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-476"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-477" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">1</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>1</sub></span></span></span><span
# class="math inline"><sub>1</sub></span> <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-28-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x2661;&lt;/mi&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-478" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-479" class="mjx-mrow"><span id="MJXc-Node-480"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.401em;">♡</span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline">♡</span></span></span><span
# class="math inline">♡</span> mov<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-29-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-481" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-482" class="mjx-mrow"><span id="MJXc-Node-483"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-484"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-485" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-30-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-486" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-487" class="mjx-mrow"><span id="MJXc-Node-488"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-489"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-490" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span> likes mov<span
# class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-31-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-491" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-492" class="mjx-mrow"><span id="MJXc-Node-493"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-494"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-495" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">1</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>1</sub></span></span></span><span
# class="math inline"><sub>1</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-32-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-496" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-497" class="mjx-mrow"><span id="MJXc-Node-498"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-499"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-500" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">3</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>3</sub></span></span></span><span
# class="math inline"><sub>3</sub></span> likes mov<span
# class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-33-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-501" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-502" class="mjx-mrow"><span id="MJXc-Node-503"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-504"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-505" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">3</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>3</sub></span></span></span><span
# class="math inline"><sub>3</sub></span></td>
# <td style="text-align: left;">Jaccard</td>
# </tr>
# <tr>
# <td style="text-align: left;">Binary<br />
# (<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-34-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x2661;&lt;/mi&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-506" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-507" class="mjx-mrow"><span id="MJXc-Node-508"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.401em;">♡</span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline">♡</span></span></span><span
# class="math inline">♡</span>, <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-35-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x2660;&lt;/mi&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-509" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-510" class="mjx-mrow"><span id="MJXc-Node-511"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.468em; padding-bottom: 0.468em;">♠</span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline">♠</span></span></span><span
# class="math inline">♠</span>)<br />
# Likes and dislikes</td>
# <td style="text-align: left;">u<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-36-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-512" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-513" class="mjx-mrow"><span id="MJXc-Node-514"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-515"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-516" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">1</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>1</sub></span></span></span><span
# class="math inline"><sub>1</sub></span> <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-37-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x2661;&lt;/mi&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-517" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-518" class="mjx-mrow"><span id="MJXc-Node-519"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.401em;">♡</span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline">♡</span></span></span><span
# class="math inline">♡</span> mov<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-38-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-520" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-521" class="mjx-mrow"><span id="MJXc-Node-522"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-523"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-524" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-39-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-525" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-526" class="mjx-mrow"><span id="MJXc-Node-527"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-528"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-529" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span> <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-40-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x2660;&lt;/mi&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-530" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-531" class="mjx-mrow"><span id="MJXc-Node-532"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.468em; padding-bottom: 0.468em;">♠</span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline">♠</span></span></span><span
# class="math inline">♠</span> mov<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-41-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-533" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-534" class="mjx-mrow"><span id="MJXc-Node-535"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-536"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-537" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">1</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>1</sub></span></span></span><span
# class="math inline"><sub>1</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-42-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-538" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-539" class="mjx-mrow"><span id="MJXc-Node-540"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-541"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-542" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span> dislikes mov<span
# class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-43-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-543" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-544" class="mjx-mrow"><span id="MJXc-Node-545"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-546"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-547" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-44-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-548" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-549" class="mjx-mrow"><span id="MJXc-Node-550"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-551"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-552" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">3</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>3</sub></span></span></span><span
# class="math inline"><sub>3</sub></span> likes mov<span
# class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-45-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-553" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-554" class="mjx-mrow"><span id="MJXc-Node-555"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-556"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-557" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">3</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>3</sub></span></span></span><span
# class="math inline"><sub>3</sub></span></td>
# <td style="text-align: left;">Jaccard</td>
# </tr>
# <tr>
# <td style="text-align: left;">Quantitative and<br />
# Ordered ratings</td>
# <td style="text-align: left;">u<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-46-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-558" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-559" class="mjx-mrow"><span id="MJXc-Node-560"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-561"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-562" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">1</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>1</sub></span></span></span><span
# class="math inline"><sub>1</sub></span> <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-47-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mo&gt;&amp;#x22C6;&lt;/mo&gt;&lt;mo&gt;&amp;#x22C6;&lt;/mo&gt;&lt;mo&gt;&amp;#x22C6;&lt;/mo&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-563" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-564" class="mjx-mrow"><span id="MJXc-Node-565"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.202em; padding-bottom: 0.335em;">⋆</span></span><span
# id="MJXc-Node-566" class="mjx-mo MJXc-space2"><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.202em; padding-bottom: 0.335em;">⋆</span></span><span
# id="MJXc-Node-567" class="mjx-mo MJXc-space2"><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.202em; padding-bottom: 0.335em;">⋆</span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline">⋆ ⋆ ⋆</span></span></span><span
# class="math inline">⋆ ⋆ ⋆</span> to mov<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-48-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-568" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-569" class="mjx-mrow"><span id="MJXc-Node-570"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-571"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-572" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-49-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-573" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-574" class="mjx-mrow"><span id="MJXc-Node-575"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-576"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-577" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span> 5-star to mov<span
# class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-50-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;1&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-578" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-579" class="mjx-mrow"><span id="MJXc-Node-580"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-581"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-582" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">1</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>1</sub></span></span></span><span
# class="math inline"><sub>1</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-51-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-583" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-584" class="mjx-mrow"><span id="MJXc-Node-585"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-586"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-587" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span> 1-star to mov<span
# class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-52-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-588" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-589" class="mjx-mrow"><span id="MJXc-Node-590"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-591"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-592" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">2</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>2</sub></span></span></span><span
# class="math inline"><sub>2</sub></span><br />
# u<span class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-53-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-593" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-594" class="mjx-mrow"><span id="MJXc-Node-595"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-596"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-597" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">3</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>3</sub></span></span></span><span
# class="math inline"><sub>3</sub></span> 3-star to mov<span
# class="MathJax_Preview" style="color: inherit;"></span><span
# id="MathJax-Element-54-Frame" class="mjx-chtml MathJax_CHTML"
# tabindex="0"
# data-mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mi&gt;&lt;/mi&gt;&lt;mn&gt;3&lt;/mn&gt;&lt;/msub&gt;&lt;/math&gt;"
# role="presentation" style="font-size: 116%; position: relative;"><span
# id="MJXc-Node-598" class="mjx-math" aria-hidden="true"><span
# id="MJXc-Node-599" class="mjx-mrow"><span id="MJXc-Node-600"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-601"
# class="mjx-mi"><span class="mjx-char"></span></span></span><span
# class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span
# id="MJXc-Node-602" class="mjx-mn" style=""><span
# class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.401em; padding-bottom: 0.335em;">3</span></span></span></span></span></span><span
# class="MJX_Assistive_MathML" role="presentation"><span
# class="math inline"><sub>3</sub></span></span></span><span
# class="math inline"><sub>3</sub></span></td>
# <td style="text-align: left;">Pearson<br />
# Cosine</td>
# </tr>
# </tbody>
# </table>
#
# ------------------------------------------------------------------------
#
# ## A Note on Representation Learning<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#A-Note-on-Representation-Learning"
# class="anchor-link">¶</a>
#
# Representation learning is about learning useful features or
# representations of data that simplify the process of downstream tasks
# such as classification, regression, or clustering. Unlike traditional
# feature engineering, where features are manually designed,
# representation learning automates this process, often uncovering
# high-dimensional, non-linear structures in data. Techniques such as
# autoencoders, convolutional neural networks, and transformers are strong
# in extracting meaningful features from raw inputs like images, text, and
# audio. By leveraging these learned representations, models become more
# robust, generalizable, and effective at handling complex data.
#
# Representation learning uses methods from linear algebra, optimization,
# and probability theory. The process is the mapping of raw data
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-55-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msup&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;R&lt;/mi&gt;&lt;/mrow&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-603"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-604"
# class="mjx-mrow"><span id="MJXc-Node-605"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">x</span></span><span id="MJXc-Node-606"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-607"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-608"
# class="mjx-texatom"><span id="MJXc-Node-609"
# class="mjx-mrow"><span id="MJXc-Node-610"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">R</span></span></span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.615em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-611"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">n</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$x \in \mathbb{R}^{n}$</span></span>$x \in \mathbb{R}^n$
# to a latent space <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-56-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msup&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;R&lt;/mi&gt;&lt;/mrow&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-612"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-613"
# class="mjx-mrow"><span id="MJXc-Node-614"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em; padding-right: 0.003em;">z</span></span><span id="MJXc-Node-615"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-616"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-617"
# class="mjx-texatom"><span id="MJXc-Node-618"
# class="mjx-mrow"><span id="MJXc-Node-619"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">R</span></span></span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.615em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-620"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">m</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$z \in \mathbb{R}^{m}$</span></span>$z \in \mathbb{R}^m$
# (where typically <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-57-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;&amp;lt;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-621"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-622"
# class="mjx-mrow"><span id="MJXc-Node-623"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">m</span></span><span id="MJXc-Node-624"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">\<</span></span><span id="MJXc-Node-625"
# class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">n</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$m < n$</span></span>$m < n$), preserving
# information essential for the task. This is achieved by solving
# optimization problems like minimizing a loss function,
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-58-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi class=&quot;MJX-tex-caligraphic&quot; mathvariant=&quot;script&quot;&gt;L&lt;/mi&gt;&lt;/mrow&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;x&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;z&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-626"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-627"
# class="mjx-mrow"><span id="MJXc-Node-628"
# class="mjx-texatom"><span id="MJXc-Node-629"
# class="mjx-mrow"><span id="MJXc-Node-630"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-cal-R"
# style="padding-top: 0.427em; padding-bottom: 0.366em;">L</span></span></span></span><span id="MJXc-Node-631"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">(</span></span><span id="MJXc-Node-632"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">x</span></span><span id="MJXc-Node-633"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-634"
# class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em; padding-right: 0.003em;">z</span></span><span id="MJXc-Node-635"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">)</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$\mathcal{L}(x,z)$</span></span>$\mathcal{L}(x,z)$,
# which measures reconstruction error or task-specific performance. Linear
# transformations (e.g., matrix multiplication) combined with non-linear
# activations (e.g., ReLU or sigmoid) help model complex relationships. In
# a probabilistic setting, methods like Variational Autoencoders (VAEs)
# use the Kullback-Leibler divergence to enforce prior constraints on
# latent variables. Similarly, the interplay of eigenvalues and
# eigenvectors in techniques like PCA and singular value decomposition
# (SVD) reveals data's principal components, underscoring the core
# mathematical principles of representation learning.
#
# Representation learning can provide the mathematical foundation for
# recommender systems by enabling the decomposition and transformation of
# user-item interaction data into a shared latent space. Formally, given a
# user-item interaction matrix <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-59-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msup&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;R&lt;/mi&gt;&lt;/mrow&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-636"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-637"
# class="mjx-mrow"><span id="MJXc-Node-638"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span><span id="MJXc-Node-639"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-640"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-641"
# class="mjx-texatom"><span id="MJXc-Node-642"
# class="mjx-mrow"><span id="MJXc-Node-643"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">R</span></span></span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.615em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-644"
# class="mjx-texatom" style=""><span id="MJXc-Node-645"
# class="mjx-mrow"><span id="MJXc-Node-646"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">m</span></span><span id="MJXc-Node-647"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-648"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">n</span></span></span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R \in \mathbb{R}^{m \times n}$</span></span>$R \in \mathbb{R}^{m \times n}$,
# where <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-60-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-649"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-650"
# class="mjx-mrow"><span id="MJXc-Node-651"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">m</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$m$</span></span>$m$ and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-61-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-652"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-653"
# class="mjx-mrow"><span id="MJXc-Node-654"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">n</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$n$</span></span>$n$ represent the number of users
# and items, respectively, matrix factorization techniques approximate
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-62-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-655"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-656"
# class="mjx-mrow"><span id="MJXc-Node-657"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R$</span></span>$R$ as the product of two
# low-dimensional matrices: <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-63-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msup&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;R&lt;/mi&gt;&lt;/mrow&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-658"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-659"
# class="mjx-mrow"><span id="MJXc-Node-660"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span><span id="MJXc-Node-661"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-662"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-663"
# class="mjx-texatom"><span id="MJXc-Node-664"
# class="mjx-mrow"><span id="MJXc-Node-665"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">R</span></span></span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.615em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-666"
# class="mjx-texatom" style=""><span id="MJXc-Node-667"
# class="mjx-mrow"><span id="MJXc-Node-668"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">m</span></span><span id="MJXc-Node-669"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-670"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$U \in \mathbb{R}^{m \times k}$</span></span>$U \in \mathbb{R}^{m \times k}$
# and <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-64-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mo&gt;&amp;#x2208;&lt;/mo&gt;&lt;msup&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi mathvariant=&quot;double-struck&quot;&gt;R&lt;/mi&gt;&lt;/mrow&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/mrow&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-671"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-672"
# class="mjx-mrow"><span id="MJXc-Node-673"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span><span id="MJXc-Node-674"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.245em; padding-bottom: 0.366em;">∈</span></span><span id="MJXc-Node-675"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"><span id="MJXc-Node-676"
# class="mjx-texatom"><span id="MJXc-Node-677"
# class="mjx-mrow"><span id="MJXc-Node-678"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-ams-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">R</span></span></span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.615em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-679"
# class="mjx-texatom" style=""><span id="MJXc-Node-680"
# class="mjx-mrow"><span id="MJXc-Node-681"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">n</span></span><span id="MJXc-Node-682"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-683"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$V \in \mathbb{R}^{n \times k}$</span></span>$V \in \mathbb{R}^{n \times k}$,
# where <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-65-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x226A;&lt;/mo&gt;&lt;mo movablelimits=&quot;true&quot; form=&quot;prefix&quot;&gt;min&lt;/mo&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mo&gt;&amp;#x2061;&lt;/mo&gt;&lt;/mrow&gt;&lt;mo stretchy=&quot;false&quot;&gt;(&lt;/mo&gt;&lt;mi&gt;m&lt;/mi&gt;&lt;mo&gt;,&lt;/mo&gt;&lt;mi&gt;n&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;)&lt;/mo&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-684"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-685"
# class="mjx-mrow"><span id="MJXc-Node-686"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span><span id="MJXc-Node-687"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.306em; padding-bottom: 0.427em;">≪</span></span><span id="MJXc-Node-688"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">min</span></span><span id="MJXc-Node-689"
# class="mjx-texatom MJXc-space1"><span id="MJXc-Node-690"
# class="mjx-mrow"><span id="MJXc-Node-691"
# class="mjx-mo"><span class="mjx-char"></span></span></span></span><span id="MJXc-Node-692"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">(</span></span><span id="MJXc-Node-693"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">m</span></span><span id="MJXc-Node-694"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="margin-top: -0.179em; padding-bottom: 0.548em;">,</span></span><span id="MJXc-Node-695"
# class="mjx-mi MJXc-space1"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.245em; padding-bottom: 0.306em;">n</span></span><span id="MJXc-Node-696"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">)</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$k \ll \min(m,n)$</span></span>$k \ll \min⁡(m,n)$.
# The rows of <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-66-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-697"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-698"
# class="mjx-mrow"><span id="MJXc-Node-699"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$U$</span></span>$U$ and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-67-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-700"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-701"
# class="mjx-mrow"><span id="MJXc-Node-702"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$V$</span></span>$V$ represent latent embeddings for
# users and items, respectively. The predicted interaction between a user
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-68-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-703"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-704"
# class="mjx-mrow"><span id="MJXc-Node-705"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$i$</span></span>$i$ and item
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-69-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-706"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-707"
# class="mjx-mrow"><span id="MJXc-Node-708"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.487em;">j</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$j$</span></span>$j$ is computed as
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-70-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msub&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mover&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;mo stretchy=&quot;false&quot;&gt;&amp;#x005E;&lt;/mo&gt;&lt;/mover&gt;&lt;/mrow&gt;&lt;mrow class=&quot;MJX-TeXAtom-ORD&quot;&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;/mrow&gt;&lt;/msub&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mi&gt;i&lt;/mi&gt;&lt;/msub&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msubsup&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi&gt;j&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x22A4;&lt;/mi&gt;&lt;/msubsup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-709"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-710"
# class="mjx-mrow"><span id="MJXc-Node-711"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-712"
# class="mjx-texatom"><span id="MJXc-Node-713"
# class="mjx-mrow"><span id="MJXc-Node-714"
# class="mjx-munderover"><span class="mjx-stack"><span class="mjx-over"
# style="height: 0.213em; padding-bottom: 0.06em; padding-left: 0.213em;"><span id="MJXc-Node-716"
# class="mjx-mo"
# style="vertical-align: top;"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">^</span></span></span><span class="mjx-op"><span id="MJXc-Node-715"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span></span></span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-717"
# class="mjx-texatom" style=""><span id="MJXc-Node-718"
# class="mjx-mrow"><span id="MJXc-Node-719"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span><span id="MJXc-Node-720"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.487em;">j</span></span></span></span></span></span><span id="MJXc-Node-721"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.064em; padding-bottom: 0.306em;">=</span></span><span id="MJXc-Node-722"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"
# style="margin-right: -0.084em;"><span id="MJXc-Node-723"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;"><span id="MJXc-Node-724"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.306em;">i</span></span></span></span><span id="MJXc-Node-725"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.003em; padding-bottom: 0.306em;">⋅</span></span><span id="MJXc-Node-726"
# class="mjx-msubsup MJXc-space2"><span class="mjx-base"
# style="margin-right: -0.186em;"><span id="MJXc-Node-727"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span><span class="mjx-stack"
# style="vertical-align: -0.311em;"><span class="mjx-sup"
# style="font-size: 70.7%; padding-bottom: 0.255em; padding-left: 0.413em; padding-right: 0.071em;"><span id="MJXc-Node-729"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">⊤</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; padding-right: 0.071em;"><span id="MJXc-Node-728"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.427em; padding-bottom: 0.487em;">j</span></span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">${\hat{R}}_{ij} = U_{i} \cdot V_{j}^{\top}$</span></span>$\hat{R}_{ij} = U_i \cdot V_j^\top$​.
# Advanced methods like neural collaborative filtering extend this
# framework by using deep neural networks to learn non-linear mappings of
# user and item features into the latent space. Similarly, graph-based
# methods utilize representation learning to encode user-item interactions
# as edge weights in a graph and learn embeddings via techniques such as
# GNNs. These mathematical formulations enable recommender systems to
# uncover latent structures in the data, predict missing entries, and
# generalize to new interactions.
#
# ------------------------------------------------------------------------
#
# ## Dataset and Feature Exploration<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Dataset-and-Feature-Exploration"
# class="anchor-link">¶</a>
#
# -   Examine the dataset, do sanity checks, extract indices
#     -   Original movie dataset is exported from a database
# -   Extract Genres
# -   Limit the number of users `USERS_N` for faster processing
# -   Use a threshold `RATINGS_N_MIN` to ease the pre-processing
#     -   movies with little information may not help
# -   `Ratings` matrix, `N` users, and `M` movies are stored in an order 2
#     tensor for faster processing
# -   Implement distance metrics
# -   Inspect distance metrics on users
#     -   What is the feature vector?
#
# Let's see how we use distance/similarity metrics to find and rate
# movies.
#
# In \[3\]:
#
#     %matplotlib inline
#     import matplotlib.pyplot as plt
#     plt.rcParams["figure.dpi"] = 72
#     import numpy as np
#     import pandas as pd
#     import re
#     from collections import defaultdict
#
# In \[4\]:
#
#     # A subset of the dataset to shorten the pipeline processing
#     USERS_N = 1000
#
# In \[5\]:
#
#     # read datasets
#     df_movies = pd.read_csv('/EP_datasets/movielens_movie.csv')
#     df_ratings = pd.read_csv('/EP_datasets/movielens_rating.csv')
#     df_tag = pd.read_csv('/EP_datasets/movielens_tag.csv')
#
#     df_genome_tags = pd.read_csv('/EP_datasets/movielens_genome_tags.csv')
#     df_genome_scores = pd.read_csv('/EP_datasets/movielens_genome_scores.csv')
#
# In \[6\]:
#
#     df_movies.head()
#
# Out\[6\]:
#
# |  | movieId | title | genres |
# |----|----|----|----|
# | 0 | 1 | Toy Story (1995) | Adventure\|Animation\|Children\|Comedy\|Fantasy |
# | 1 | 2 | Jumanji (1995) | Adventure\|Children\|Fantasy |
# | 2 | 3 | Grumpier Old Men (1995) | Comedy\|Romance |
# | 3 | 4 | Waiting to Exhale (1995) | Comedy\|Drama\|Romance |
# | 4 | 5 | Father of the Bride Part II (1995) | Comedy |
#
# In \[7\]:
#
#     df_ratings.head()
#
# Out\[7\]:
#
# |     | userId | movieId | rating | timestamp           |
# |-----|--------|---------|--------|---------------------|
# | 0   | 1      | 2       | 3.5    | 2005-04-02 23:53:47 |
# | 1   | 1      | 29      | 3.5    | 2005-04-02 23:31:16 |
# | 2   | 1      | 32      | 3.5    | 2005-04-02 23:33:39 |
# | 3   | 1      | 47      | 3.5    | 2005-04-02 23:32:07 |
# | 4   | 1      | 50      | 3.5    | 2005-04-02 23:29:40 |
#
# In \[8\]:
#
#     df_tag.head()
#
# Out\[8\]:
#
# |     | userId | movieId | tag           | timestamp           |
# |-----|--------|---------|---------------|---------------------|
# | 0   | 18     | 4141    | Mark Waters   | 2009-04-24 18:19:40 |
# | 1   | 65     | 208     | dark hero     | 2013-05-10 01:41:18 |
# | 2   | 65     | 353     | dark hero     | 2013-05-10 01:41:19 |
# | 3   | 65     | 521     | noir thriller | 2013-05-10 01:39:43 |
# | 4   | 65     | 592     | dark hero     | 2013-05-10 01:41:18 |
#
# In \[9\]:
#
#     df_genome_tags.head()
#
# Out\[9\]:
#
# |     | tagId | tag          |
# |-----|-------|--------------|
# | 0   | 1     | 007          |
# | 1   | 2     | 007 (series) |
# | 2   | 3     | 18th century |
# | 3   | 4     | 1920s        |
# | 4   | 5     | 1930s        |
#
# In \[10\]:
#
#     df_genome_scores.head()
#
# Out\[10\]:
#
# |     | movieId | tagId | relevance |
# |-----|---------|-------|-----------|
# | 0   | 1       | 1     | 0.02500   |
# | 1   | 1       | 2     | 0.02500   |
# | 2   | 1       | 3     | 0.05775   |
# | 3   | 1       | 4     | 0.09675   |
# | 4   | 1       | 5     | 0.14675   |
#
# In \[11\]:
#
#     print(f"Number of unique movies= {len(df_movies)}")
#     print(f"Number of unique users= {len(df_ratings.userId.unique())}")
#
#     print(f"Number of unique rated movies= {len(df_ratings.movieId.unique())} (not all movies are rated by users)")
#
#     # MovieLens rating system
#     print(f"Number of tags= {len(df_genome_tags)}")
#     print(f"Number of tagger users= {len(df_tag.userId.unique())} (who created/assigned tags)")
#     print(f"Number of created unrefined tags= {len(df_tag.tag.unique())} (created tags, not-refined tags)")
#
#     Genres = defaultdict(int)
#     for genre in df_movies.genres:
#         if 'no' not in genre:
#             m = re.findall(r"([A-Za-z-]+)(?=\||$)", genre)
#             if m:
#                 for gen in m:
#                     Genres[gen] += 1
#
#     print(f"Number of genres= {len(Genres.keys())}")
#
#     Number of unique movies= 27278
#     Number of unique users= 138493
#     Number of unique rated movies= 26744 (not all movies are rated by users)
#     Number of tags= 1128
#     Number of tagger users= 7801 (who created/assigned tags)
#     Number of created unrefined tags= 38644 (created tags, not-refined tags)
#     Number of genres= 19
#
# In \[12\]:
#
#     # genres
#     gens = sorted(Genres.keys())
#
#     plt.figure(figsize=(10,5), dpi=72)
#     plt.bar(gens, [Genres[g] for g in gens])
#     plt.xticks(rotation=90, fontsize=12)
#     plt.grid(axis='y')
#     plt.title('Genres')
#     plt.show()
#
# In \[13\]:
#
#     # explore ratings data
#     Rating_Min, Rating_Max = df_ratings.rating.min(), df_ratings.rating.max()
#     print(Rating_Min, Rating_Max)
#
#     0.5 5.0
#
# In \[14\]:
#
#     # movies index
#     movies = df_ratings.movieId.unique()
#     MoviesIndex = {mov:i for i, mov in enumerate(movies)}
#     MoviesIndexRev = {MoviesIndex[mov]:mov for mov in MoviesIndex.keys()}
#
#     print(len(MoviesIndex.keys()), len(MoviesIndexRev.keys()))
#
#     26744 26744
#
# In \[15\]:
#
#     %%time
#
#     # rating matrix N-by-M, users-by-movies
#
#     # N = len(df_ratings.userId.unique())
#     N = USERS_N  # Full problem as above
#     M = len(MoviesIndex.keys())
#     Ratings = np.zeros((N,M), dtype=np.float32)
#
#     for _, row in df_ratings.iterrows():
#         if row.userId > USERS_N:  # Shorten the problem dataset
#             break
#         Ratings[row.userId-1, MoviesIndex[row.movieId]] = row.rating
#
#     CPU times: total: 4.28 s
#     Wall time: 4.28 s
#
# In \[16\]:
#
#     # remove movies that have min number of ratings from the user list
#     RATINGS_N_MIN= 20
#
#     moviesnull = np.where(np.count_nonzero(Ratings, axis=0) <= RATINGS_N_MIN)[0]
#     moviesnull = [MoviesIndexRev[_] for _ in moviesnull]
#
#     print(len(moviesnull))
#
#     25038
#
# In \[17\]:
#
#     # movies index
#     movies = list(set(df_ratings.movieId.unique().tolist()) - set(moviesnull))
#     MoviesIndex = {mov:i for i, mov in enumerate(movies)}
#     MoviesIndexRev = {MoviesIndex[mov]:mov for mov in MoviesIndex.keys()}
#
#     print(len(MoviesIndex.keys()), len(MoviesIndexRev.keys()))
#
#     1706 1706
#
# In \[18\]:
#
#     # update the rating matrix
#     M = len(MoviesIndex.keys())
#     Ratings = np.zeros((N,M), dtype=np.float32)
#
#     for _, row in df_ratings.iterrows():
#         if row.userId > USERS_N:  # Shorten the problem dataset
#             break
#         if row.movieId in MoviesIndex:  # Skip low count rated movies
#             Ratings[row.userId-1, MoviesIndex[row.movieId]] = row.rating
#
#     print(Ratings.shape)  # number of users, number of movies
#
#     (1000, 1706)
#
# In \[19\]:
#
#     # sanity
#     moviesnull = np.where(np.count_nonzero(Ratings, axis=0) <= RATINGS_N_MIN)[0]
#
#     print(len(moviesnull))
#
#     0
#
# In \[18\]:
#
#     # distance metrics
#
#     def sim_jaccard(_a:np.ndarray, _b:np.ndarray)->float:
#         ix = np.where((_a>0.) & (_b>0.))
#         ixd = np.where((_a>0.) | (_b>0.))
#         return ix[0].shape[0] / ixd[0].shape[0]
#
#     def sim_costeta(_a:np.ndarray, _b:np.ndarray)->float:
#         from numpy.linalg import norm
#         assert _a.shape == _b.shape, 'require vectors same shape'
#         return np.dot(_a, _b) / (norm(_a)*norm(_b))
#
#     def sim_pearson(_a:np.ndarray, _b:np.ndarray)->float:
#         ix = np.where((_a>0.) & (_b>0.))
#         if ix[0].shape[0] == 0:
#             return 0.
#         _ua, _ub = np.mean(_a[ix]), np.mean(_b[ix])
#         num = (_a[ix]-_ua) @ (_b[ix]-_ub).T
#         den  = np.sqrt(np.sum((_a[ix]-_ua)**2)) * np.sqrt(np.sum((_b[ix]-_ub)**2))
#         if den == 0.:
#             return 0.
#         return num/den
#
#     def dist_L1(_a:np.ndarray, _b:np.ndarray)->float:
#         ix = np.where((_a>0.) & (_b>0.))
#         if ix[0].shape[0] == 0:
#             return 1.
#         return np.sum(np.abs(_a[ix]-_b[ix])) / ix[0].shape[0]
#
#     def dist_L2(_a:np.ndarray, _b:np.ndarray)->float:
#         ix = np.where((_a>0.) & (_b>0.))
#         if ix[0].shape[0] == 0:
#             return 1.
#         return np.sqrt(np.sum((_a[ix]-_b[ix])**2)) / ix[0].shape[0]
#
#     def dist_cheby(_a:np.ndarray, _b:np.ndarray)->float:
#         ix = np.where((_a>0.) & (_b>0.))
#         if ix[0].shape[0] == 0:
#             return 1.
#         return np.max(np.abs(_a[ix]-_b[ix])) / (Rating_Max-Rating_Min)
#
#     DistanceMetrics = [(sim_jaccard, 'Jaccard (sim)'), (sim_costeta, 'CosTeta (sim)'), (sim_pearson, 'Pearson (sim)'),
#                        (dist_L1, 'L1 (dist)'), (dist_L2, 'L2 (dist)'), (dist_cheby, 'Chebyshev (dist)')]
#
# In \[19\]:
#
#     # distances
#     USER_A, USER_B = 0, 1
#
#     x1, x2 = Ratings[USER_A], Ratings[USER_B]
#
#     for metric in DistanceMetrics:
#         print(f'{metric[1]:<17} {metric[0](x1, x2):.3f}')
#
#     Jaccard (sim)     0.053
#     CosTeta (sim)     0.133
#     Pearson (sim)     -0.069
#     L1 (dist)         1.167
#     L2 (dist)         0.412
#     Chebyshev (dist)  0.444
#
# In \[20\]:
#
#     Users = [0, 1, 2, 3, 4]
#
#     # example, user Users to other users histogram for these six distance metrics
#     fig, ax = plt.subplots(nrows=2, ncols=3, sharex='none', sharey='all', figsize=(15, 9), dpi=72)
#
#     for i, metric in enumerate(DistanceMetrics):
#         for u in Users:
#             d = [metric[0](Ratings[u], Ratings[_]) for _ in range(N)]
#             h = np.histogram(d, bins=50)
#             ax.flatten()[i].plot(h[1][:-1], h[0], label=f'user {u:d}', alpha=0.7)
#         ax.flatten()[i].set_title(metric[1])
#         ax.flatten()[i].legend(loc='upper right')
#         ax.flatten()[i].grid()
#
# ------------------------------------------------------------------------
#
# ## Collaborative Filtering<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Collaborative-Filtering"
# class="anchor-link">¶</a>
#
# Online retailers, bookshops, and libraries sometimes have
# recommendations saying, "If you liked this popular book X, then you may
# also try this (not-so-much-popular) book Y." These remarks are directed
# toward a large group of people and often work well, and they are similar
# to a filtered chart. A more robust approach is to create individualized
# content lists or, at least, lists for small groups of like-minded users.
# A database of preferences for items by users to predict additional
# topics or products a new user might like.
#
# ### User-based Neighborhood-based Filtering<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#User-based-Neighborhood-based-Filtering"
# class="anchor-link">¶</a>
#
# 1.  For a particular user, compute the similarity to the *other users*
# 2.  Order *users* by similarity
# 3.  Select a *neighborhood of users* close to the *active user*
# 4.  Compute the predicted rating from that neighborhood
#
# ### Item-based Filtering<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Item-based-Filtering"
# class="anchor-link">¶</a>
#
# 1.  For a particular item, compute the similarity to the *other items*
# 2.  Order *items* by similarity
# 3.  Select a *neighborhood of items* close to the *active item*
# 4.  Compute the predicted rating from that neighborhood
#
# The `Ratings` matrix will be used in both filters to compute
# similarities.
#
# In an alternative approach, the item similarities might be computed
# using the **tags** and **tag scoring**. This would be equivalent to
# **content-based** approach. Note that tags are computed by another
# pipeline or annotated/tagged by experts/users.
#
# ------------------------------------------------------------------------
#
# ## User-based Example<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#User-based-Example"
# class="anchor-link">¶</a>
#
# -   Find out what a user would score a particular movie that he/she did
#     not score (or watch)
#     -   Similarity will be based on users
# -   Use `sim_costeta` for similarity (can try other ones)
# -   The distance matrix is `N`-by-`N`
# -   Always use `float32` for speed
#
# In \[21\]:
#
#     # User-based filtering
#     OUR_USER= 0
#     OUR_ITEM= 0  # pick an item which our user did not rate
#     OUR_USER_NEIGHBORHOOD= 50  # number of users similar to our user
#
# In \[22\]:
#
#     # users who rated our item
#     ix_users = np.where(Ratings[:,OUR_ITEM]>0.)[0]
#
# In \[23\]:
#
#     %%time
#
#     # generate a distance matrix - user
#     Dist_u = np.zeros((N,N), dtype=np.float32)
#     for i in range(N):
#         for j in range(N):
#             Dist_u[i,j] = sim_costeta(Ratings[i,:], Ratings[j,:])
#
#     CPU times: total: 3.83 s
#     Wall time: 3.83 s
#
# In \[24\]:
#
#     # Pearson generates -1 to +1
#     d = np.abs(Dist_u[OUR_USER,ix_users])
#     ix_best = np.argsort(-d)[:OUR_USER_NEIGHBORHOOD]
#     users = ix_users[ix_best]
#
# In \[25\]:
#
#     Dist_u[OUR_USER,users]
#
# Out\[25\]:
#
#     array([0.40457195, 0.376088  , 0.3636198 , 0.36297017, 0.36068535,
#            0.35957903, 0.35941103, 0.35755163, 0.3565974 , 0.34926307,
#            0.34772184, 0.3475802 , 0.34442246, 0.34433424, 0.34246457,
#            0.3385418 , 0.33742315, 0.3373577 , 0.3327701 , 0.33230612,
#            0.3305398 , 0.3281719 , 0.3254474 , 0.32429686, 0.32400984,
#            0.32379663, 0.32297403, 0.3224957 , 0.32155728, 0.32003078,
#            0.3195294 , 0.31799585, 0.31655583, 0.31534153, 0.31273744,
#            0.31241196, 0.3090288 , 0.30858234, 0.3075587 , 0.3062176 ,
#            0.30284712, 0.30217868, 0.30106026, 0.29852498, 0.29817006,
#            0.29561612, 0.29506028, 0.2946949 , 0.2922781 , 0.2906266 ],
#           dtype=float32)
#
# In \[26\]:
#
#     ratings = np.array([Ratings[_,OUR_ITEM] for _ in users])
#
#     print(f'The user not rated the item= {Ratings[OUR_USER, OUR_ITEM]:.1f}')
#     print(f'Average rating in user-neighborhood= {ratings.mean():.1f}')
#
#     The user not rated the item= 0.0
#     Average rating in user-neighborhood= 3.9
#
# **Outcome:** The user did not rate the item. Other users in the
# neighborhood of this user rated the item with an average computed above.
#
# ------------------------------------------------------------------------
#
# ## Item-based Example<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Item-based-Example"
# class="anchor-link">¶</a>
#
# -   Find out what a user would score a particular movie that he/she did
#     not score (or watch)
#     -   Similarity will be based on items
# -   Use `sim_costeta` for similarity (can try other ones)
# -   The distance matrix is `M`-by-`M`
# -   Always use `float32` for speed
#
# In \[27\]:
#
#     # Item-based filtering
#     OUR_USER= 0
#     OUR_ITEM= 0  # pick an item which our user did not rate
#     OUR_ITEM_NEIGHBORHOOD= 50  # number of items similar to our item
#
# In \[28\]:
#
#     # users who rated our item
#     users = np.where(Ratings[:,OUR_ITEM]>0.)[0]
#
# In \[29\]:
#
#     %%time
#
#     # generate a distance matrix - item
#     Dist_i = np.zeros((M,M), dtype=np.float32)
#     for i in range(M):
#         for j in range(M):
#             Dist_i[i,j] = sim_costeta(Ratings[:,i], Ratings[:,j])
#
#     CPU times: total: 16.6 s
#     Wall time: 16.6 s
#
# In \[30\]:
#
#     d = np.abs(Dist_i[OUR_ITEM,:])
#     ix_best = np.argsort(-d)[:OUR_ITEM_NEIGHBORHOOD]
#     items = ix_best
#
# In \[31\]:
#
#     Dist_i[OUR_ITEM,items]
#
# Out\[31\]:
#
#     array([1.        , 0.5504396 , 0.5502418 , 0.5399177 , 0.53434914,
#            0.5339682 , 0.5261372 , 0.52247614, 0.5207451 , 0.5182745 ,
#            0.5171993 , 0.5162483 , 0.5151485 , 0.51244044, 0.5092254 ,
#            0.5065545 , 0.49518365, 0.49036434, 0.48994136, 0.48688045,
#            0.48679808, 0.4855667 , 0.48526853, 0.4845558 , 0.48364452,
#            0.4789724 , 0.47775424, 0.47728276, 0.47648945, 0.47547597,
#            0.4751349 , 0.47399274, 0.47177908, 0.4688636 , 0.46806997,
#            0.46561712, 0.46376756, 0.46283498, 0.46212852, 0.45594773,
#            0.4524766 , 0.4489189 , 0.44841185, 0.44607133, 0.44498888,
#            0.44414526, 0.44198734, 0.44049805, 0.4375241 , 0.43522343],
#           dtype=float32)
#
# In \[32\]:
#
#     ratings = np.array([Ratings[users,_] for _ in items])
#
#     print(f'The user not rated the item= {Ratings[OUR_USER, OUR_ITEM]:.1f}')
#     print(f'Average rating in item-neighborhood= {ratings.mean():.1f}')
#
#     The user not rated the item= 0.0
#     Average rating in item-neighborhood= 1.8
#
# **Outcome:** The user did not rate the item. Other items in the
# neighborhood of this item has the average score as above.
#
# ------------------------------------------------------------------------
#
# ## Content-based Approach: Cluster the Items<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Content-based-Approach:-Cluster-the-Items"
# class="anchor-link">¶</a>
#
# Item category can help a user select a relevant item. In addition, the
# user selections and scores can guide the recommender system in
# predicting what category a user likes more than the others. Creating
# item genres or item categories can be accomplished via clustering item
# features. These features can also be some augmented information provided
# by experts (or even movie critics). In this example, we can use movie
# titles (plots, information extracted from the Web, or even parsing movie
# scripts) to create a movie feature vector. Note that in our dataset,
# there are also tags that capture this kind of information.
#
# Use the following two resources:
#
# 1.  `gensim` GloVe 📚
#     **<a href="https://radimrehurek.com/gensim/index.html"
#     target="_blank">Gensim</a>** = "Generate Similar" is a topic
#     modeling library to implement Latent Semantic Methods, and it is
#     licensed under
#     **<a href="https://www.gnu.org/licenses/old-licenses/lgpl-2.1.en.html"
#     target="_blank">GNU LGPLv2.1 license</a>**
# 2.  GloVe embedding model with feature size `M=100` using 🧩
#     **<a href="https://nlp.stanford.edu/projects/glove/"
#     target="_blank">https://nlp.stanford.edu/projects/glove/</a>**
#
# `gensim` library can download GloVe word embeddings to be used as word
# vectors in text processing. A movie is represented by its title and the
# average word vectors it constitutes (Word2Vec is another method to
# represent a text phrase).
#
# The GloVe project is an embedding approach trained by very large
# corpora, specifically indexed words consistently, to improve sharing
# across problems and domains. The selected embedding is `M=100`
# dimensions, 400K words.
#
# The number of genres might be a good starting point as the number of
# clusters is expected.
#
# Let's represent each movie by its average word embedding extracted from
# its title and cluster.
#
# **Important:** We need to ensure the word is in the Glove dictionary -
# use lowercase words, etc.
#
# In \[33\]:
#
#     import gensim.downloader
#
#     print(f'gensim version= {gensim.__version__}')
#     Glove = gensim.downloader.load('glove-wiki-gigaword-100')
#
#     GLOVE_M = 100
#
#     gensim version= 4.3.0
#
# In \[34\]:
#
#     # restart movie index due to filtering as in the previous Cells
#     movies = sorted(df_ratings.movieId.unique())
#     MoviesIndex = {mov:i for i, mov in enumerate(movies)}
#     MoviesIndexRev = {MoviesIndex[mov]:mov for mov in MoviesIndex.keys()}
#
#     M_titles = len(MoviesIndex.keys())
#
# In \[35\]:
#
#     # populate titles, extract tokens
#     Titles, TitleGenres, TitlesParsed = [None]*M_titles, [None]*M_titles, [None]*M_titles
#     for _, row in df_movies.iterrows():
#         if row.movieId in MoviesIndex:
#             Titles[MoviesIndex[row.movieId]] = row.title
#             TitleGenres[MoviesIndex[row.movieId]] = re.search(r'[\w\-]+', row.genres).group(0)  # use only the first one
#
#     for _, title in enumerate(Titles):
#         TitlesParsed[_] = re.findall(r'[a-z]+', title.lower())
#
#     # sanity
#     print(Titles[:5])
#     print(TitlesParsed[:5])
#     print(TitleGenres[:5])
#
#     ['Toy Story (1995)', 'Jumanji (1995)', 'Grumpier Old Men (1995)', 'Waiting to Exhale (1995)', 'Father of the Bride Part II (1995)']
#     [['toy', 'story'], ['jumanji'], ['grumpier', 'old', 'men'], ['waiting', 'to', 'exhale'], ['father', 'of', 'the', 'bride', 'part', 'ii']]
#     ['Adventure', 'Adventure', 'Comedy', 'Comedy', 'Comedy']
#
# In \[36\]:
#
#     # take the average word vectors to represent titles in GloVe embeddings
#     X = np.zeros((M_titles, GLOVE_M), dtype=np.float32)
#     for _, title in enumerate(TitlesParsed):
#         v = []
#         if len(title) == 0:
#             # movie title empty after parsing, setting to zero vector
#             X[_] = np.zeros(GLOVE_M, dtype=np.float32)
#         else:
#             for w in title:
#                 v += [Glove[w]] if w in Glove else [np.zeros(GLOVE_M, dtype=np.float32)]
#             X[_] = np.mean(np.array(v), axis=0)  # average
#
# In \[37\]:
#
#     from sklearn.cluster import KMeans
#
#     # use number of genres to cluster
#     K = len(Genres.keys())
#     Clusters = KMeans(n_clusters=K, n_init=10).fit_predict(X)
#
# In \[38\]:
#
#     # Print a few movie titles and their cluster IDs in a genre
#     GENRE = 'Horror'
#     n_results = 20
#     for _, g in enumerate(TitleGenres):
#         if g == GENRE and n_results > 0:
#             print(f'{Clusters[_]:2d}  {Titles[_]:s}')
#             n_results -= 1
#
#      4  Lord of Illusions (1995)
#     10  Species (1995)
#     11  Castle Freak (1995)
#     18  Relative Fear (1994)
#      4  Tales from the Crypt Presents: Demon Knight (1995)
#      8  Village of the Damned (1995)
#      8  Fear, The (1995)
#      8  In the Mouth of Madness (1995)
#     13  Body Snatchers (1993)
#      4  Puppet Masters, The (1994)
#      2  301, 302 (301/302) (1995)
#     12  Cemetery Man (Dellamorte Dellamore) (1994)
#     13  Thinner (1996)
#      8  Spirits of the Dead (1968)
#     12  Eyes Without a Face (Yeux sans visage, Les) (1959)
#      4  Relic, The (1997)
#      4  Halloween: The Curse of Michael Myers (Halloween 6: The Curse of Michael Myers) (1995)
#      8  Night of the Living Dead (1968)
#      8  Children of the Corn IV: The Gathering (1996)
#      8  Fog, The (1980)
#
# In \[39\]:
#
#     # Print a few movie titles and their cluster IDs in a genre
#     GENRE = 'War'
#     n_results = 20
#     for _, g in enumerate(TitleGenres):
#         if g == GENRE and n_results > 0:
#             print(f'{Clusters[_]:2d}  {Titles[_]:s}')
#             n_results -= 1
#
#     16  Pharaoh's Army (1995)
#      8  Walk in the Sun, A (1945)
#      4  Prisoner of the Mountains (Kavkazsky plennik) (1996)
#     13  Pork Chop Hill (1959)
#      5  Run Silent Run Deep (1958)
#      8  Cross of Iron (1977)
#      4  Devil's Brigade, The (1968)
#      9  Story of G.I. Joe (1945)
#     14  Anzio (1968)
#      8  Lion of the Desert (1980)
#     16  Attack Force Z (a.k.a. The Z Men) (Z-tzu te kung tui) (1982)
#     18  Objective, Burma! (1945)
#      8  Battle of Britain (1969)
#     12  Duel at Diablo (1966)
#     16  Murphy's War (1971)
#     12  Plainsman, The (1937)
#      8  In Enemy Hands (2004)
#      1  Bataan (1943)
#      0  Villa Rides! (1968)
#      4  Battle for Haditha (2007)
#
# **Question:** How do you assess the performance of this clustering? Do
# you expect above clustering will work on titles for other genres?
#
# ------------------------------------------------------------------------
#
# ## Matrix Factorization Techniques<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Matrix-Factorization-Techniques"
# class="anchor-link">¶</a>
#
# Matrix factorization is a core technique in recommender systems, widely
# used for collaborative filtering. Decomposing the large, sparse
# user-item interaction matrix `Ratings` (<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-71-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-730"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-731"
# class="mjx-mrow"><span id="MJXc-Node-732"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R$</span></span>$R$) into the product of two
# lower-dimensional matrices: a user latent feature matrix
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-72-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-733"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-734"
# class="mjx-mrow"><span id="MJXc-Node-735"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$U$</span></span>$U$ and an item latent feature
# matrix <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-73-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-736"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-737"
# class="mjx-mrow"><span id="MJXc-Node-738"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$V$</span></span>$V$. These latent matrices capture
# hidden factors influencing user preferences and item characteristics.
# The goal is to approximate <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-74-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-739"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-740"
# class="mjx-mrow"><span id="MJXc-Node-741"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R$</span></span>$R$ by minimizing the
# reconstruction error, typically using optimization techniques such as
# gradient descent or alternating least squares (ALS). By projecting both
# users and items into the same latent space, matrix factorization enables
# efficient prediction of unknown interactions, thereby personalizing
# recommendations. Extensions of matrix factorization, like singular value
# decomposition (SVD) and non-negative matrix factorization (NMF), are
# adapted to enhance interpretability, sparsity, or scalability, making
# the approach suitable for real-world applications with high number
# (e.g., millions) of users and items.
#
# ### Singular Value Decomposition<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Singular-Value-Decomposition"
# class="anchor-link">¶</a>
#
# SVD is a mathematical technique used to factorize a matrix into three
# components: <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-75-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x22A4;&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-742"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-743"
# class="mjx-mrow"><span id="MJXc-Node-744"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">A</span></span><span id="MJXc-Node-745"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.064em; padding-bottom: 0.306em;">=</span></span><span id="MJXc-Node-746"
# class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span><span id="MJXc-Node-747"
# class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-size1-R"
# style="padding-top: 0.548em; padding-bottom: 0.548em;">∑</span></span><span id="MJXc-Node-748"
# class="mjx-msubsup MJXc-space1"><span class="mjx-base"
# style="margin-right: -0.186em;"><span id="MJXc-Node-749"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0.413em; padding-right: 0.071em;"><span id="MJXc-Node-750"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">⊤</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$A = U\sum V^{\top}$</span></span>$A=U \sum V^\top$,
# where <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-76-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;A&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-751"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-752"
# class="mjx-mrow"><span id="MJXc-Node-753"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">A</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$A$</span></span>$A$ is the original matrix,
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-77-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-754"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-755"
# class="mjx-mrow"><span id="MJXc-Node-756"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$U$</span></span>$U$ and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-78-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-757"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-758"
# class="mjx-mrow"><span id="MJXc-Node-759"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$V$</span></span>$V$ are orthogonal matrices, and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-79-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-760"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-761"
# class="mjx-mrow"><span id="MJXc-Node-762"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R"
# style="padding-top: 0.548em; padding-bottom: 0.548em;">∑</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$\sum$</span></span>$\sum$ is a diagonal matrix of
# singular values. In recommender systems, SVD is commonly applied to
# decompose the user-item interaction matrix and extract latent factors
# representing users and items. By retaining only the
# top-<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-80-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-763"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-764"
# class="mjx-mrow"><span id="MJXc-Node-765"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$k$</span></span>$k$ singular values, we can reduce
# dimensionality and capture the most significant features, improving
# generalization and computational efficiency. The scipy package
# `sparse.linalg` has an implementation of SVD, named `svds`.
#
# Given a user-item matrix <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-81-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-766"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-767"
# class="mjx-mrow"><span id="MJXc-Node-768"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R$</span></span>$R$ of dimensions
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-82-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-769"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-770"
# class="mjx-mrow"><span id="MJXc-Node-771"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span><span id="MJXc-Node-772"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-773"
# class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$N \times M$</span></span>$N \times M$:
#
# -   <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-83-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-774"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-775"
#     class="mjx-mrow"><span id="MJXc-Node-776"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$U$</span></span>$U$:
#     <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-84-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-777"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-778"
#     class="mjx-mrow"><span id="MJXc-Node-779"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span><span id="MJXc-Node-780"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-781"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$N \times N$</span></span>$N \times N$
#     orthogonal matrix (left singular vectors)
# -   <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-85-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-782"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-783"
#     class="mjx-mrow"><span id="MJXc-Node-784"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R"
#     style="padding-top: 0.548em; padding-bottom: 0.548em;">∑</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$\sum$</span></span>$\sum$:
#     <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-86-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-785"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-786"
#     class="mjx-mrow"><span id="MJXc-Node-787"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span><span id="MJXc-Node-788"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-789"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$N \times M$</span></span>$N \times M$ diagonal
#     matrix (singular values
# -   <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-87-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;msup&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x22A4;&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-790"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-791"
#     class="mjx-mrow"><span id="MJXc-Node-792"
#     class="mjx-msubsup"><span class="mjx-base"
#     style="margin-right: -0.186em;"><span id="MJXc-Node-793"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span><span class="mjx-sup"
#     style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0.413em; padding-right: 0.071em;"><span id="MJXc-Node-794"
#     class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">⊤</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$V^{\top}$</span></span>$V^\top$:
#     <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-88-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-795"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-796"
#     class="mjx-mrow"><span id="MJXc-Node-797"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span><span id="MJXc-Node-798"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-799"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$M \times M$</span></span>$M \times M$
#     orthogonal matrix (right singular vectors)
#
# The approximation is achieved by truncating
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-89-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-800"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-801"
# class="mjx-mrow"><span id="MJXc-Node-802"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R"
# style="padding-top: 0.548em; padding-bottom: 0.548em;">∑</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$\sum$</span></span>$\sum$ to rank
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-90-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-803"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-804"
# class="mjx-mrow"><span id="MJXc-Node-805"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$k$</span></span>$k$, resulting in
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-91-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;mo&gt;&amp;#x2248;&lt;/mo&gt;&lt;msub&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/msub&gt;&lt;munder&gt;&lt;mo&gt;&amp;#x2211;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/munder&gt;&lt;msubsup&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi&gt;K&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x22A4;&lt;/mi&gt;&lt;/msubsup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-806"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-807"
# class="mjx-mrow"><span id="MJXc-Node-808"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span><span id="MJXc-Node-809"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">≈</span></span><span id="MJXc-Node-810"
# class="mjx-msubsup MJXc-space3"><span class="mjx-base"
# style="margin-right: -0.084em;"><span id="MJXc-Node-811"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.219em; padding-right: 0.071em;"><span id="MJXc-Node-812"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span><span id="MJXc-Node-813"
# class="mjx-munderover MJXc-space1"><span class="mjx-base"><span id="MJXc-Node-814"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-size1-R"
# style="padding-top: 0.548em; padding-bottom: 0.548em;">∑</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; vertical-align: -0.439em; padding-right: 0.071em;"><span id="MJXc-Node-815"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span><span id="MJXc-Node-816"
# class="mjx-msubsup MJXc-space1"><span class="mjx-base"
# style="margin-right: -0.186em;"><span id="MJXc-Node-817"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span><span class="mjx-stack"
# style="vertical-align: -0.327em;"><span class="mjx-sup"
# style="font-size: 70.7%; padding-bottom: 0.255em; padding-left: 0.413em; padding-right: 0.071em;"><span id="MJXc-Node-819"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">⊤</span></span></span><span class="mjx-sub"
# style="font-size: 70.7%; padding-right: 0.071em;"><span id="MJXc-Node-818"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.04em;">K</span></span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R \approx U_{k}\sum\limits_{k}V_{K}^{\top}$</span></span>$R \approx U_k \sum_k V_K^\top$.
#
# ### Alternating Least Squares<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Alternating-Least-Squares"
# class="anchor-link">¶</a>
#
# ALS is a matrix factorization technique specifically designed for sparse
# data, like the `Ratings` matrix above, often used in collaborative
# filtering. It minimizes the reconstruction error of the user-item
# interaction matrix by iteratively solving least squares optimization
# problems. The algorithm alternates between fixing user or item factors
# and solving for the other, ensuring computational efficiency. The Apache
# Spark package `pyspark` has an implementation of ALS.
#
# Given <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-92-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-820"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-821"
# class="mjx-mrow"><span id="MJXc-Node-822"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R$</span></span>$R$, ALS approximates it as
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-93-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;mo&gt;&amp;#x2248;&lt;/mo&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x22A4;&lt;/mi&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-823"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-824"
# class="mjx-mrow"><span id="MJXc-Node-825"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span><span id="MJXc-Node-826"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">≈</span></span><span id="MJXc-Node-827"
# class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span><span id="MJXc-Node-828"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.003em; padding-bottom: 0.306em;">⋅</span></span><span id="MJXc-Node-829"
# class="mjx-msubsup MJXc-space2"><span class="mjx-base"
# style="margin-right: -0.186em;"><span id="MJXc-Node-830"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0.413em; padding-right: 0.071em;"><span id="MJXc-Node-831"
# class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">⊤</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R \approx U \cdot V^{\top}$</span></span>$R \approx U \cdot V^\top$,
# where:
#
# -   <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-94-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-832"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-833"
#     class="mjx-mrow"><span id="MJXc-Node-834"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$U$</span></span>$U$ is the user latent feature
#     matrix (<span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-95-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-835"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-836"
#     class="mjx-mrow"><span id="MJXc-Node-837"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span><span id="MJXc-Node-838"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-839"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$N \times k$</span></span>$N \times k$)
# -   <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-96-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-840"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-841"
#     class="mjx-mrow"><span id="MJXc-Node-842"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$V$</span></span>$V$ is the item latent feature
#     matrix (<span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-97-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-843"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-844"
#     class="mjx-mrow"><span id="MJXc-Node-845"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span><span id="MJXc-Node-846"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-847"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$M \times k$</span></span>$M \times k$)
#
# For each iteration, the optimization alternates:
#
# -   Fix <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-98-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-848"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-849"
#     class="mjx-mrow"><span id="MJXc-Node-850"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$V$</span></span>$V$, solve
#     <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-99-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;arg&lt;/mi&gt;&lt;mo&gt;&amp;#x2061;&lt;/mo&gt;&lt;munder&gt;&lt;mo form=&quot;prefix&quot;&gt;min&lt;/mo&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;/munder&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x22A4;&lt;/mi&gt;&lt;/msup&gt;&lt;msup&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;msup&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-851"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-852"
#     class="mjx-mrow"><span id="MJXc-Node-853"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span><span id="MJXc-Node-854"
#     class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.064em; padding-bottom: 0.306em;">=</span></span><span id="MJXc-Node-855"
#     class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.185em; padding-bottom: 0.548em;">arg</span></span><span id="MJXc-Node-856"
#     class="mjx-mo"><span class="mjx-char"></span></span><span id="MJXc-Node-857"
#     class="mjx-munder MJXc-space1"><span class="mjx-itable"><span class="mjx-row"><span class="mjx-cell"><span class="mjx-op"><span id="MJXc-Node-858"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">min</span></span></span></span></span><span class="mjx-row"><span class="mjx-under"
#     style="font-size: 70.7%; padding-top: 0.236em; padding-bottom: 0.141em; padding-left: 0.795em;"><span id="MJXc-Node-859"
#     class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span></span></span></span><span id="MJXc-Node-860"
#     class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span><span id="MJXc-Node-861"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span><span id="MJXc-Node-862"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.306em; padding-bottom: 0.427em;">−</span></span><span id="MJXc-Node-863"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span><span id="MJXc-Node-864"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.003em; padding-bottom: 0.306em;">⋅</span></span><span id="MJXc-Node-865"
#     class="mjx-msubsup MJXc-space2"><span class="mjx-base"
#     style="margin-right: -0.186em;"><span id="MJXc-Node-866"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span><span class="mjx-sup"
#     style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0.413em; padding-right: 0.071em;"><span id="MJXc-Node-867"
#     class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">⊤</span></span></span></span><span id="MJXc-Node-868"
#     class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-869"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span></span><span class="mjx-sup"
#     style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-870"
#     class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">2</span></span></span></span><span id="MJXc-Node-871"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.306em; padding-bottom: 0.427em;">+</span></span><span id="MJXc-Node-872"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em;">λ</span></span><span id="MJXc-Node-873"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span><span id="MJXc-Node-874"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span><span id="MJXc-Node-875"
#     class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-876"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span></span><span class="mjx-sup"
#     style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-877"
#     class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">2</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$U = \arg\min\limits_{U}\| R - U \cdot V^{\top}\|^{2} + \lambda\| U\|^{2}$</span></span>$U = \arg\underset{U}{\min} \|R − U \cdot V^\top\|^2 + \lambda \|U\|^2$
# -   Fix <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-100-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-878"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-879"
#     class="mjx-mrow"><span id="MJXc-Node-880"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$U$</span></span>$U$, solve
#     <span class="MathJax_Preview"
#     style="color: inherit;"></span><span id="MathJax-Element-101-Frame"
#     class="mjx-chtml MathJax_CHTML" tabindex="0"
#     mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mo&gt;=&lt;/mo&gt;&lt;mi&gt;arg&lt;/mi&gt;&lt;mo&gt;&amp;#x2061;&lt;/mo&gt;&lt;munder&gt;&lt;mo form=&quot;prefix&quot;&gt;min&lt;/mo&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;/munder&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;U&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;msup&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;mi mathvariant=&quot;normal&quot;&gt;&amp;#x22A4;&lt;/mi&gt;&lt;/msup&gt;&lt;msup&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;mo&gt;+&lt;/mo&gt;&lt;mi&gt;&amp;#x03BB;&lt;/mi&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mi&gt;V&lt;/mi&gt;&lt;msup&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;"
#     role="presentation"
#     style="font-size: 118%; position: relative;"><span id="MJXc-Node-881"
#     class="mjx-math" aria-hidden="true"><span id="MJXc-Node-882"
#     class="mjx-mrow"><span id="MJXc-Node-883"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span><span id="MJXc-Node-884"
#     class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.064em; padding-bottom: 0.306em;">=</span></span><span id="MJXc-Node-885"
#     class="mjx-mi MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.185em; padding-bottom: 0.548em;">arg</span></span><span id="MJXc-Node-886"
#     class="mjx-mo"><span class="mjx-char"></span></span><span id="MJXc-Node-887"
#     class="mjx-munder MJXc-space1"><span class="mjx-itable"><span class="mjx-row"><span class="mjx-cell"><span class="mjx-op"><span id="MJXc-Node-888"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">min</span></span></span></span></span><span class="mjx-row"><span class="mjx-under"
#     style="font-size: 70.7%; padding-top: 0.236em; padding-bottom: 0.141em; padding-left: 0.794em;"><span id="MJXc-Node-889"
#     class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span></span></span></span><span id="MJXc-Node-890"
#     class="mjx-mo MJXc-space1"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span><span id="MJXc-Node-891"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span><span id="MJXc-Node-892"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.306em; padding-bottom: 0.427em;">−</span></span><span id="MJXc-Node-893"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.084em;">U</span></span><span id="MJXc-Node-894"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.003em; padding-bottom: 0.306em;">⋅</span></span><span id="MJXc-Node-895"
#     class="mjx-msubsup MJXc-space2"><span class="mjx-base"
#     style="margin-right: -0.186em;"><span id="MJXc-Node-896"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span></span><span class="mjx-sup"
#     style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0.413em; padding-right: 0.071em;"><span id="MJXc-Node-897"
#     class="mjx-mi" style=""><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">⊤</span></span></span></span><span id="MJXc-Node-898"
#     class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-899"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span></span><span class="mjx-sup"
#     style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-900"
#     class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">2</span></span></span></span><span id="MJXc-Node-901"
#     class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.306em; padding-bottom: 0.427em;">+</span></span><span id="MJXc-Node-902"
#     class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em;">λ</span></span><span id="MJXc-Node-903"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span><span id="MJXc-Node-904"
#     class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
#     style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.186em;">V</span></span><span id="MJXc-Node-905"
#     class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-906"
#     class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span></span><span class="mjx-sup"
#     style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-907"
#     class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R"
#     style="padding-top: 0.366em; padding-bottom: 0.366em;">2</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
#     role="presentation">$V = \arg\min\limits_{V}\| R - U \cdot V^{\top}\|^{2} + \lambda\| V\|^{2}$</span></span>$V = \arg\underset{V}{\min} \|R − U \cdot V^\top\|^2 + \lambda \|V\|^2$
#
# ### Non-negative Matrix Factorization<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Non-negative-Matrix-Factorization"
# class="anchor-link">¶</a>
#
# NMF is a matrix factorization approach where all matrix elements are
# constrained to be non-negative, making it particularly suitable for
# datasets where negative values lack interpretation (e.g., user
# preferences or counts). It factors <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-102-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-908"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-909"
# class="mjx-mrow"><span id="MJXc-Node-910"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R$</span></span>$R$ into two non-negative matrices
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-103-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;W&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-911"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-912"
# class="mjx-mrow"><span id="MJXc-Node-913"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.104em;">W</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$W$</span></span>$W$ and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-104-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-914"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-915"
# class="mjx-mrow"><span id="MJXc-Node-916"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.057em;">H</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$H$</span></span>$H$, ensuring interpretability and
# sparsity.
#
# Given <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-105-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-917"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-918"
# class="mjx-mrow"><span id="MJXc-Node-919"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$R$</span></span>$R$, <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-106-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;W&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-920"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-921"
# class="mjx-mrow"><span id="MJXc-Node-922"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.104em;">W</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$W$</span></span>$W$ (<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-107-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;N&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-923"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-924"
# class="mjx-mrow"><span id="MJXc-Node-925"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.085em;">N</span></span><span id="MJXc-Node-926"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-927"
# class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$N \times k$</span></span>$N \times k$) user feature
# matrix, <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-108-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-928"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-929"
# class="mjx-mrow"><span id="MJXc-Node-930"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.057em;">H</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$H$</span></span>$H$ (<span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-109-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;k&lt;/mi&gt;&lt;mo&gt;&amp;#x00D7;&lt;/mo&gt;&lt;mi&gt;M&lt;/mi&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-931"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-932"
# class="mjx-mrow"><span id="MJXc-Node-933"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">k</span></span><span id="MJXc-Node-934"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.185em; padding-bottom: 0.306em;">×</span></span><span id="MJXc-Node-935"
# class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.081em;">M</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$k \times M$</span></span>$k \times M$) item feature
# matrix, the objective is to minimize <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-110-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mi&gt;R&lt;/mi&gt;&lt;mo&gt;&amp;#x2212;&lt;/mo&gt;&lt;mi&gt;W&lt;/mi&gt;&lt;mo&gt;&amp;#x22C5;&lt;/mo&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;msup&gt;&lt;mo fence=&quot;false&quot; stretchy=&quot;false&quot;&gt;&amp;#x2016;&lt;/mo&gt;&lt;mn&gt;2&lt;/mn&gt;&lt;/msup&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-936"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-937"
# class="mjx-mrow"><span id="MJXc-Node-938"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span><span id="MJXc-Node-939"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em;">R</span></span><span id="MJXc-Node-940"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.306em; padding-bottom: 0.427em;">−</span></span><span id="MJXc-Node-941"
# class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.104em;">W</span></span><span id="MJXc-Node-942"
# class="mjx-mo MJXc-space2"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.003em; padding-bottom: 0.306em;">⋅</span></span><span id="MJXc-Node-943"
# class="mjx-mi MJXc-space2"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.057em;">H</span></span><span id="MJXc-Node-944"
# class="mjx-msubsup"><span class="mjx-base"><span id="MJXc-Node-945"
# class="mjx-mo"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.487em; padding-bottom: 0.608em;">∥</span></span></span><span class="mjx-sup"
# style="font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;"><span id="MJXc-Node-946"
# class="mjx-mn" style=""><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">2</span></span></span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$\| R - W \cdot H\|^{2}$</span></span>$\|R − W \cdot H\|^2$,
# subject to <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-111-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;W&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-947"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-948"
# class="mjx-mrow"><span id="MJXc-Node-949"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.104em;">W</span></span><span id="MJXc-Node-950"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.487em;">≥</span></span><span id="MJXc-Node-951"
# class="mjx-mn MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">0</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$W \geq 0$</span></span>$W \ge 0$ and
# <span class="MathJax_Preview"
# style="color: inherit;"></span><span id="MathJax-Element-112-Frame"
# class="mjx-chtml MathJax_CHTML" tabindex="0"
# mathml="&lt;math xmlns=&quot;http://www.w3.org/1998/Math/MathML&quot;&gt;&lt;mi&gt;H&lt;/mi&gt;&lt;mo&gt;&amp;#x2265;&lt;/mo&gt;&lt;mn&gt;0&lt;/mn&gt;&lt;/math&gt;"
# role="presentation"
# style="font-size: 118%; position: relative;"><span id="MJXc-Node-952"
# class="mjx-math" aria-hidden="true"><span id="MJXc-Node-953"
# class="mjx-mrow"><span id="MJXc-Node-954"
# class="mjx-mi"><span class="mjx-char MJXc-TeX-math-I"
# style="padding-top: 0.487em; padding-bottom: 0.306em; padding-right: 0.057em;">H</span></span><span id="MJXc-Node-955"
# class="mjx-mo MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.487em;">≥</span></span><span id="MJXc-Node-956"
# class="mjx-mn MJXc-space3"><span class="mjx-char MJXc-TeX-main-R"
# style="padding-top: 0.366em; padding-bottom: 0.366em;">0</span></span></span></span><span class="MJX_Assistive_MathML"
# role="presentation">$H \geq 0$</span></span>$H \ge 0$. This is solved
# iteratively using multiplicative updates. The sklearn package
# `decomposition` has an implementation of NMF.
#
# ------------------------------------------------------------------------
#
# ## Emerging Trends in Recommender Systems<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Emerging-Trends-in-Recommender-Systems"
# class="anchor-link">¶</a>
#
# -   Federated learning for recommenders
# -   Privacy-preserving recommendations
# -   Zero-shot and few-shot learning for recommendations
# -   Personalization in recommender systems
# -   Large language models in recommendation systems
#
# ------------------------------------------------------------------------
#
# ## References<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#References"
# class="anchor-link">¶</a>
#
# 1.  Falk, Kim. Practical recommender systems. Simon and Schuster, 2019.
# 2.  Harper, F. Maxwell, and Joseph A. Konstan. "The movielens datasets:
#     History and context." Acm transactions on interactive intelligent
#     systems (tiis) 5.4 (2015): 1-19.
# 3.  Su, Xiaoyuan, and Taghi M. Khoshgoftaar. "A survey of collaborative
#     filtering techniques." Advances in artificial intelligence 2009
#     (2009).
#
# ------------------------------------------------------------------------
#
# ## Exercises<a
# href="https://cdn.inst-fs-iad-prod.inscloudgate.net/06448a8c-81dc-41dd-aa09-def9b5837a1d/module01_aml_recommender_notebook.html?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCIsImtpZCI6ImNkbiJ9.eyJyZXNvdXJjZSI6Ii8wNjQ0OGE4Yy04MWRjLTQxZGQtYWEwOS1kZWY5YjU4MzdhMWQvbW9kdWxlMDFfYW1sX3JlY29tbWVuZGVyX25vdGVib29rLmh0bWwiLCJ0ZW5hbnQiOiJjYW52YXMiLCJ1c2VyX2lkIjoiMTMwNDQwMDAwMDAwMDM4OTI3IiwiaWF0IjoxNzM3NTIxODU0LCJleHAiOjE3Mzc2MDgyNTR9.gyTQ2HlrI3bO5FyGHilk2YMWcBuBV0gTwWYaSx-rHjLot29sTeJVcmItIEPWIksd09apr-eiL8naOqZBIo9KIA&amp;content_type=text%2Fhtml#Exercises"
# class="anchor-link">¶</a>
#
# **Exercise 1.** Reduce the number of items by updating the minimum
# number of ratings and rerun the analysis.
#
# **Exercise 2.** Why did the item filtering reveal a much lower rating
# than the user? How do you remedy this?
#
# **Exercise 3.** Implement content-based filtering by generating
# similarities between movies based on their tags.
#
# ------------------------------------------------------------------------
#
# In \[40\]:
#
#     %%html
#     <style>
#         table {margin-left: 0 !important;}
#         p {font-family: verdana;}
#         li {font-family: verdana;}
#         div {font-size: 10pt;}
#     </style>
#     <!-- Display markdown tables left oriented in this notebook. -->
#
# ------------------------------------------------------------------------
#
# ------------------------------------------------------------------------
